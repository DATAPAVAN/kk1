# %%
import pandas as pd

# %%
a=pd.read_excel(r'C:\Users\HP\Downloads\Attribute DataSet (1).xlsx')

# %%
a[5:20]
# Out:
#       Dress_ID     Style    Price  Rating  Size  Season         NeckLine  \
# 5   1068332458  bohemian      Low     0.0     M  Summer           v-neck
# 6   1220707172    Casual  Average     0.0    XL  Summer           o-neck
# 7   1219677488   Novelty  Average     0.0  free  Automn           o-neck
# 8   1113094204     Flare  Average     0.0  free  Spring           v-neck
# 9    985292672  bohemian      Low     0.0  free  Summer           v-neck
# 10  1117293701     party  Average     5.0  free  Summer           o-neck
# 11   898481530     Flare  Average     0.0  free  Spring           v-neck
# 12   957723897      sexy      Low     4.7     M  Winter           o-neck
# 13   749031896   vintage  Average     4.8     M  Summer           o-neck
# 14  1055411544    Casual      Low     5.0     M  Summer        boat-neck
# 15  1162628131    Casual      Low     0.0  free  Winter        boat-neck
# 16   624314841      cute  Average     4.7     L  spring           o-neck
# 17   830467746  bohemian   Medium     5.0  free  Automn           o-neck
# 18   840857118     Brief  Average     0.0     M  Winter  peterpan-collor
# 19  1113221101      Sexy  Average     5.0     M  Automn           o-neck
#
#     SleeveLength waiseline  Material  FabricType Decoration Pattern Type  \
# 5      sleevless    empire       NaN         NaN        NaN        print
# 6           full       NaN    cotton         NaN        NaN        solid
# 7          short   natural  polyster  broadcloth       lace          NaN
# 8          short    empire    cotton  broadcloth    beading        solid
# 9      sleevless   natural     nylon     chiffon        NaN          NaN
# 10          full   natural  polyster  broadcloth       lace        solid
# 11         short       NaN     nylon         NaN        NaN       animal
# 12  threequarter       NaN       NaN     chiffon       lace        print
# 13         short    empire    cotton      jersey        NaN       animal
# 14         short       NaN    cotton         NaN     sashes        solid
# 15          full       NaN     other       other       lace          NaN
# 16         short       NaN    cotton         NaN     sashes        solid
# 17          full   natural       NaN         NaN  hollowout    patchwork
# 18  threequarter   natural    cotton         NaN        NaN    patchwork
# 19     sleevless    empire  milksilk         NaN        NaN          NaN
#
#     Recommendation
# 5                0
# 6                0
# 7                0
# 8                1
# 9                1
# 10               0
# 11               0
# 12               1
# 13               1
# 14               0
# 15               0
# 16               1
# 17               1
# 18               0
# 19               1

# %%
a
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# 1          Petal   natural     microfiber         NaN     ruffles
# 2           full   natural       polyster         NaN         NaN
# 3           full   natural           silk     chiffon  embroidary
# 4      butterfly   natural  chiffonfabric     chiffon         bow
# ..           ...       ...            ...         ...         ...
# 495         full   natural       polyster         NaN         NaN
# 496         full    empire         cotton         NaN         NaN
# 497         full    empire         cotton         NaN        lace
# 498    sleevless    empire           silk  broadcloth    applique
# 499        short    empire         cotton    Corduroy        lace
#
#     Pattern Type  Recommendation
# 0         animal               1
# 1         animal               0
# 2          print               0
# 3          print               1
# 4            dot               0
# ..           ...             ...
# 495        solid               1
# 496          NaN               0
# 497        solid               1
# 498        print               1
# 499        solid               0
#
# [500 rows x 14 columns]

# %%
b=pd.read_excel(r'C:\Users\HP\Downloads\Attribute DataSet (1).xlsx',sheet_name='pavan')

# %%
b
# Out:
#    964917582    Casual  Average    5
# 0  859922576      cute  Average  4.6
# 1  817353671  bohemian      Low  4.6
# 2  990559192     Brief  Average  4.7
# 3  713391965    Casual      Low  4.7
# 4  722565148      Sexy      Low  4.3
# 5  532874347    Casual  Average  4.7
# 6  655464934    Casual  Average  4.6
# 7  919930954    Casual      Low  4.4

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
type(b)
# Out:
# pandas.core.frame.DataFrame

# %%
 c=pd.read_excel(r'C:\Users\HP\Downloads\Attribute DataSet (1).xlsx',sheet_name='pavan',header=None,names=['A','B','C'])

# %%
c
# Out:
#                   A        B    C
# 964917582    Casual  Average  5.0
# 859922576      cute  Average  4.6
# 817353671  bohemian      Low  4.6
# 990559192     Brief  Average  4.7
# 713391965    Casual      Low  4.7
# 722565148      Sexy      Low  4.3
# 532874347    Casual  Average  4.7
# 655464934    Casual  Average  4.6
# 919930954    Casual      Low  4.4

# %%
a.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
a.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
a.head(10)
# Out:
#      Dress_ID     Style    Price  Rating  Size  Season NeckLine SleeveLength  \
# 0  1006032852      Sexy      Low     4.6     M  Summer   o-neck    sleevless
# 1  1212192089    Casual      Low     0.0     L  Summer   o-neck        Petal
# 2  1190380701   vintage     High     0.0     L  Automn   o-neck         full
# 3   966005983     Brief  Average     4.6     L  Spring   o-neck         full
# 4   876339541      cute      Low     4.5     M  Summer   o-neck    butterfly
# 5  1068332458  bohemian      Low     0.0     M  Summer   v-neck    sleevless
# 6  1220707172    Casual  Average     0.0    XL  Summer   o-neck         full
# 7  1219677488   Novelty  Average     0.0  free  Automn   o-neck        short
# 8  1113094204     Flare  Average     0.0  free  Spring   v-neck        short
# 9   985292672  bohemian      Low     0.0  free  Summer   v-neck    sleevless
#
#   waiseline       Material  FabricType  Decoration Pattern Type  \
# 0    empire            NaN     chiffon     ruffles       animal
# 1   natural     microfiber         NaN     ruffles       animal
# 2   natural       polyster         NaN         NaN        print
# 3   natural           silk     chiffon  embroidary        print
# 4   natural  chiffonfabric     chiffon         bow          dot
# 5    empire            NaN         NaN         NaN        print
# 6       NaN         cotton         NaN         NaN        solid
# 7   natural       polyster  broadcloth        lace          NaN
# 8    empire         cotton  broadcloth     beading        solid
# 9   natural          nylon     chiffon         NaN          NaN
#
#    Recommendation
# 0               1
# 1               0
# 2               0
# 3               1
# 4               0
# 5               0
# 6               0
# 7               0
# 8               1
# 9               1

# %%
a.tail(10)
# Out:
#       Dress_ID     Style    Price  Rating  Size  Season   NeckLine  \
# 490  641665398    Casual      Low     4.8  free  winter    bowneck
# 491  964917582    Casual  Average     5.0     L  Summer     o-neck
# 492  859922576      cute  Average     4.6     M  Spring     o-neck
# 493  817353671  bohemian      Low     4.6  free  Summer     o-neck
# 494  990559192     Brief  Average     4.7     M  winter     o-neck
# 495  713391965    Casual      Low     4.7     M  Spring     o-neck
# 496  722565148      Sexy      Low     4.3  free  Summer     o-neck
# 497  532874347    Casual  Average     4.7     M  Summer     v-neck
# 498  655464934    Casual  Average     4.6     L  winter  boat-neck
# 499  919930954    Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline  Material  FabricType Decoration Pattern Type  \
# 490         full   natural  polyster     chiffon        bow        solid
# 491    sleevless   natural    cotton         NaN        NaN          NaN
# 492   halfsleeve   natural   acrylic     chiffon        NaN          NaN
# 493    sleevless   natural    cotton     chiffon       none        solid
# 494   halfsleeve   natural   acrylic     chiffon        NaN      striped
# 495         full   natural  polyster         NaN        NaN        solid
# 496         full    empire    cotton         NaN        NaN          NaN
# 497         full    empire    cotton         NaN       lace        solid
# 498    sleevless    empire      silk  broadcloth   applique        print
# 499        short    empire    cotton    Corduroy       lace        solid
#
#      Recommendation
# 490               0
# 491               1
# 492               0
# 493               1
# 494               0
# 495               1
# 496               0
# 497               1
# 498               1
# 499               0

# %%
d=pd.read_csv(r'C:\Users\HP\Downloads\haberman.csv',header=None,names=['A','B','C','D'])

# %%
d
# Out:
#       A   B  C  D
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
e=pd.read_csv(r'C:\Users\HP\Downloads\haberman.csv',sep='@')

# %%
e
# Out:
#       30,64,1,1
# 0     30,62,3,1
# 1     30,65,0,1
# 2     31,59,2,1
# 3     31,65,4,1
# 4    33,58,10,1
# ..          ...
# 300   75,62,1,1
# 301   76,67,0,1
# 302   77,65,3,1
# 303   78,65,1,2
# 304   83,58,2,2
#
# [305 rows x 1 columns]

# %%
d
# Out:
#       A   B  C  D
# 0    30  64  1  1
# 1    30  62  3  1
# 2    30  65  0  1
# 3    31  59  2  1
# 4    31  65  4  1
# ..   ..  .. .. ..
# 301  75  62  1  1
# 302  76  67  0  1
# 303  77  65  3  1
# 304  78  65  1  2
# 305  83  58  2  2
#
# [306 rows x 4 columns]

# %%
f=pd.read_csv(r'C:\Users\HP\Downloads\haberman.csv',sep=",")

# %%
f
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
g=pd.read_csv(r'https://raw.githubusercontent.com/selva86/datasets/master/HouseVotes84.csv')

# %%
g
# Out:
#      Class   V1   V2 V3   V4   V5 V6   V7   V8   V9  V10  V11  V12 V13 V14  \
# 0        1    n    y  n    y    y  y    n    n    n    y  NaN    y   y   y
# 1        1    n    y  n    y    y  y    n    n    n    n    n    y   y   y
# 2        0  NaN    y  y  NaN    y  y    n    n    n    n    y    n   y   y
# 3        0    n    y  y    n  NaN  y    n    n    n    n    y    n   y   n
# 4        0    y    y  y    n    y  y    n    n    n    n    y  NaN   y   y
# ..     ...  ...  ... ..  ...  ... ..  ...  ...  ...  ...  ...  ...  ..  ..
# 430      1    n    n  y    y    y  y    n    n    y    y    n    y   y   y
# 431      0    n    n  y    n    n  n    y    y    y    y    n    n   n   n
# 432      1    n  NaN  n    y    y  y    n    n    n    n    y    y   y   y
# 433      1    n    n  n    y    y  y  NaN  NaN  NaN  NaN    n    y   y   y
# 434      1    n    y  n    y    y  y    n    n    n    y    n    y   y   y
#
#      V15  V16
# 0      n    y
# 1      n  NaN
# 2      n    n
# 3      n    y
# 4      y    y
# ..   ...  ...
# 430    n    y
# 431    n    y
# 432    n    y
# 433    n    y
# 434  NaN    n
#
# [435 rows x 17 columns]

# %%
# the above is how to view github repositery data set in my system with out downloading#

# %%
h=pd.read_html(r'https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
h
# Out:
# [      Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
#  0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
#  1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
#  2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
#  3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
#  4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
#  ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
#  670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
#  671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
#  672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
#  673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
#  674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#       DRB  TRB  AST  STL BLK  TOV   PF   PTS
#  0    222  301   68   27  22   60  147   398
#  1     19   28   16   16   7   14   24    94
#  2    324  523   66   38  86   99  222   537
#  3     54   77   15    4   9    9   30    60
#  4    220  247  129   41   7  116  167  1035
#  ..   ...  ...  ...  ...  ..  ...  ...   ...
#  670  284  411  173  124  25  117  171  1071
#  671  170  245  135   86  17   75  115   685
#  672  114  166   38   38   8   42   56   386
#  673  265  362  100   34  49   62  156   472
#  674  319  465  113   18  52   76  205   833
#
#  [675 rows x 30 columns]]

# %%
# how to read html page data without dowNloading#

# %%
type(h)
# Out:
# list

# %%
len(h)
# Out:
# 1

# %%
h[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
#      DRB  TRB  AST  STL BLK  TOV   PF   PTS
# 0    222  301   68   27  22   60  147   398
# 1     19   28   16   16   7   14   24    94
# 2    324  523   66   38  86   99  222   537
# 3     54   77   15    4   9    9   30    60
# 4    220  247  129   41   7  116  167  1035
# ..   ...  ...  ...  ...  ..  ...  ...   ...
# 670  284  411  173  124  25  117  171  1071
# 671  170  245  135   86  17   75  115   685
# 672  114  166   38   38   8   42   56   386
# 673  265  362  100   34  49   62  156   472
# 674  319  465  113   18  52   76  205   833
#
# [675 rows x 30 columns]

# %%
js=pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url          id  \
# 0     https://github.com/pandas-dev/pandas/pull/48491  1368450955
# 1     https://github.com/pandas-dev/pandas/pull/48490  1368430593
# 2     https://github.com/pandas-dev/pandas/pull/48489  1368418413
# 3   https://github.com/pandas-dev/pandas/issues/48488  1368255987
# 4   https://github.com/pandas-dev/pandas/issues/48487  1368189400
# 5     https://github.com/pandas-dev/pandas/pull/48484  1367833986
# 6   https://github.com/pandas-dev/pandas/issues/48483  1367782315
# 7   https://github.com/pandas-dev/pandas/issues/48482  1367728492
# 8   https://github.com/pandas-dev/pandas/issues/48481  1367686165
# 9   https://github.com/pandas-dev/pandas/issues/48480  1367623880
# 10  https://github.com/pandas-dev/pandas/issues/48479  1367498537
# 11  https://github.com/pandas-dev/pandas/issues/48478  1367492963
# 12    https://github.com/pandas-dev/pandas/pull/48477  1367270630
# 13  https://github.com/pandas-dev/pandas/issues/48476  1367270335
# 14    https://github.com/pandas-dev/pandas/pull/48475  1367066742
# 15    https://github.com/pandas-dev/pandas/pull/48473  1366954496
# 16  https://github.com/pandas-dev/pandas/issues/48471  1366832004
# 17  https://github.com/pandas-dev/pandas/issues/48469  1366804220
# 18  https://github.com/pandas-dev/pandas/issues/48463  1366439767
# 19  https://github.com/pandas-dev/pandas/issues/48462  1366434213
# 20  https://github.com/pandas-dev/pandas/issues/48461  1366248003
# 21  https://github.com/pandas-dev/pandas/issues/48460  1365983092
# 22  https://github.com/pandas-dev/pandas/issues/48459  1365721674
# 23    https://github.com/pandas-dev/pandas/pull/48457  1365479885
# 24    https://github.com/pandas-dev/pandas/pull/48455  1365350650
# 25    https://github.com/pandas-dev/pandas/pull/48454  1365330706
# 26  https://github.com/pandas-dev/pandas/issues/48453  1365169618
# 27  https://github.com/pandas-dev/pandas/issues/48448  1365112962
# 28  https://github.com/pandas-dev/pandas/issues/48447  1365092955
# 29    https://github.com/pandas-dev/pandas/pull/48446  1365043901
#
#                 node_id  number  \
# 0   PR_kwDOAA0YD84-tf63   48491
# 1   PR_kwDOAA0YD84-tblF   48490
# 2   PR_kwDOAA0YD84-tZF_   48489
# 3    I_kwDOAA0YD85Rje3z   48488
# 4    I_kwDOAA0YD85RjOnY   48487
# 5   PR_kwDOAA0YD84-reKm   48484
# 6    I_kwDOAA0YD85RhrOr   48483
# 7    I_kwDOAA0YD85RheFs   48482
# 8    I_kwDOAA0YD85RhTwV   48481
# 9    I_kwDOAA0YD85RhEjI   48480
# 10   I_kwDOAA0YD85Rgl8p   48479
# 11   I_kwDOAA0YD85Rgklj   48478
# 12  PR_kwDOAA0YD84-pmfh   48477
# 13   I_kwDOAA0YD85RfuO_   48476
# 14  PR_kwDOAA0YD84-o6jn   48475
# 15  PR_kwDOAA0YD84-oiQK   48473
# 16   I_kwDOAA0YD85ReDOE   48471
# 17   I_kwDOAA0YD85Rd8b8   48469
# 18   I_kwDOAA0YD85RcjdX   48463
# 19   I_kwDOAA0YD85RciGl   48462
# 20   I_kwDOAA0YD85Rb0pD   48461
# 21   I_kwDOAA0YD85Raz90   48460
# 22   I_kwDOAA0YD85RZ0JK   48459
# 23  PR_kwDOAA0YD84-jbET   48457
# 24  PR_kwDOAA0YD84-i_Ej   48455
# 25  PR_kwDOAA0YD84-i6vV   48454
# 26   I_kwDOAA0YD85RXtXS   48453
# 27   I_kwDOAA0YD85RXfiC   48448
# 28   I_kwDOAA0YD85RXapb   48447
# 29  PR_kwDOAA0YD84-h_5Q   48446
#
#                                                 title  ... closed_at  \
# 0           WEB: Update Python for Data Analysis book  ...       NaT
# 1   CI: Use -j1 for python-dev build to avoid flak...  ...       NaT
# 2                        BUG: fix test_arrow.py tests  ...       NaT
# 3              ENH: df.compare should have tolerances  ...       NaT
# 4                                DOC: pandas.read_csv  ...       NaT
# 5   BUG: fix valueError for groupby with empty inp...  ...       NaT
# 6   BUG: [unit test] pandas/io/clipboard/__init__....  ...       NaT
# 7   BUG: replace with immutable data raising KeyEr...  ...       NaT
# 8   ENH: Support "std" aggregation in groupby for ...  ...       NaT
# 9   BUG: df.fillna(dict, inplace=True) triggers Fu...  ...       NaT
# 10            ENH: initialize row DataFrame with list  ...       NaT
# 11           ENH: Add serialization options to to_csv  ...       NaT
# 12  BUG: GroupBy equates different types of null v...  ...       NaT
# 13  BUG: groupby doesn't distinguish between diffe...  ...       NaT
# 14  DOC: Remove storage options from doc of Styler...  ...       NaT
# 15  REGR: .describe on unsigned dtypes results in ...  ...       NaT
# 16  BUG: The var SIGNED_INT_PYARROW_DTYPES has inc...  ...       NaT
# 17  ENH: Remove ArrowStringArray and StringDtype("...  ...       NaT
# 18  BUG: Non-deterministic merge results & failing...  ...       NaT
# 19                      Governance: pandas workgroups  ...       NaT
# 20                 BUG: exeception on NDFrame.replace  ...       NaT
# 21  TYP/DOC:  date_range (and other *_range) funct...  ...       NaT
# 22  BUG: Calling sample() on an empty GroupbyDataF...  ...       NaT
# 23  TST: Fix unsigned pyarrow types in SIGNED_INT_...  ...       NaT
# 24        DOC: Add missing API item to reference docs  ...       NaT
# 25        DEPR: allowing unknown array-likes in merge  ...       NaT
# 26   API: find_common_type([dt64tz1, dt64tz2]) -> UTC  ...       NaT
# 27  BUG: Multiples of QuarterOffset not respected ...  ...       NaT
# 28  ENH: Support masked ExtensionTypes when using ...  ...       NaT
# 29  BUG: Index.equals raising with index of tuples...  ...       NaT
#
#    author_association active_lock_reason  draft  \
# 0              MEMBER                NaN    0.0
# 1              MEMBER                NaN    0.0
# 2              MEMBER                NaN    0.0
# 3         CONTRIBUTOR                NaN    NaN
# 4                NONE                NaN    NaN
# 5         CONTRIBUTOR                NaN    0.0
# 6                NONE                NaN    NaN
# 7                NONE                NaN    NaN
# 8                NONE                NaN    NaN
# 9                NONE                NaN    NaN
# 10               NONE                NaN    NaN
# 11               NONE                NaN    NaN
# 12             MEMBER                NaN    1.0
# 13             MEMBER                NaN    NaN
# 14        CONTRIBUTOR                NaN    0.0
# 15             MEMBER                NaN    0.0
# 16        CONTRIBUTOR                NaN    NaN
# 17        CONTRIBUTOR                NaN    NaN
# 18               NONE                NaN    NaN
# 19             MEMBER                NaN    NaN
# 20               NONE                NaN    NaN
# 21        CONTRIBUTOR                NaN    NaN
# 22        CONTRIBUTOR                NaN    NaN
# 23        CONTRIBUTOR                NaN    0.0
# 24             MEMBER                NaN    0.0
# 25             MEMBER                NaN    0.0
# 26             MEMBER                NaN    NaN
# 27               NONE                NaN    NaN
# 28             MEMBER                NaN    NaN
# 29             MEMBER                NaN    0.0
#
#                                          pull_request  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3                                                 NaN
# 4                                                 NaN
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13                                                NaN
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                                  body  \
# 0                                                None
# 1   xref #47305\r\n\r\ne.g. https://github.com/pan...
# 2                               Sits on top of #48428
# 3   ### Feature Type\n\n- [ ] Adding new functiona...
# 4   ### Pandas version checks\r\n\r\n- [X] I have ...
# 5   - [x] closes ##48459\r\n- [x] [Tests added and...
# 6   ### Pandas version checks\r\n\r\n- [X] I have ...
# 7   ### Pandas version checks\n\n- [X] I have chec...
# 8   ### Pandas version checks\n\n- [X] I have chec...
# 9   ### Pandas version checks\n\n- [X] I have chec...
# 10  ### Feature Type\n\n- [ ] Adding new functiona...
# 11  ### Feature Type\n\n- [ ] Adding new functiona...
# 12  - [x] closes #48476 (Replace xxxx with the Git...
# 13  ```\r\ndf = pd.DataFrame({'a': [np.nan, pd.NA,...
# 14  Remove parameter from doc string that is not i...
# 15  - [x] closes #48340 (Replace xxxx with the Git...
# 16  ### Pandas version checks\n\n- [X] I have chec...
# 17  ### Feature Type\r\n\r\n- [ ] Adding new funct...
# 18  ### Pandas version checks\n\n- [X] I have chec...
# 19  xref #47694, #47706\r\n\r\nI think the organiz...
# 20  ### Pandas version checks\n\n- [X] I have chec...
# 21  I'm coming from a question in pandas-dev/panda...
# 22  ### Pandas version checks\n\n- [X] I have chec...
# 23  - [x] closes #48471 48471\r\n- [x] [Tests adde...
# 24  - [x] All [code checks passed](https://pandas....
# 25  Not sure what the current status is w/r/t new ...
# 26  ATM find_common_type between two different Dat...
# 27  ### Pandas version checks\n\n- [X] I have chec...
# 28  Currently any `engine="numba"` operation is on...
# 29  - [ ] closes #xxxx (Replace xxxx with the Gith...
#
#                                             reactions  \
# 0   {'url': 'https://api.github.com/repos/pandas-d...
# 1   {'url': 'https://api.github.com/repos/pandas-d...
# 2   {'url': 'https://api.github.com/repos/pandas-d...
# 3   {'url': 'https://api.github.com/repos/pandas-d...
# 4   {'url': 'https://api.github.com/repos/pandas-d...
# 5   {'url': 'https://api.github.com/repos/pandas-d...
# 6   {'url': 'https://api.github.com/repos/pandas-d...
# 7   {'url': 'https://api.github.com/repos/pandas-d...
# 8   {'url': 'https://api.github.com/repos/pandas-d...
# 9   {'url': 'https://api.github.com/repos/pandas-d...
# 10  {'url': 'https://api.github.com/repos/pandas-d...
# 11  {'url': 'https://api.github.com/repos/pandas-d...
# 12  {'url': 'https://api.github.com/repos/pandas-d...
# 13  {'url': 'https://api.github.com/repos/pandas-d...
# 14  {'url': 'https://api.github.com/repos/pandas-d...
# 15  {'url': 'https://api.github.com/repos/pandas-d...
# 16  {'url': 'https://api.github.com/repos/pandas-d...
# 17  {'url': 'https://api.github.com/repos/pandas-d...
# 18  {'url': 'https://api.github.com/repos/pandas-d...
# 19  {'url': 'https://api.github.com/repos/pandas-d...
# 20  {'url': 'https://api.github.com/repos/pandas-d...
# 21  {'url': 'https://api.github.com/repos/pandas-d...
# 22  {'url': 'https://api.github.com/repos/pandas-d...
# 23  {'url': 'https://api.github.com/repos/pandas-d...
# 24  {'url': 'https://api.github.com/repos/pandas-d...
# 25  {'url': 'https://api.github.com/repos/pandas-d...
# 26  {'url': 'https://api.github.com/repos/pandas-d...
# 27  {'url': 'https://api.github.com/repos/pandas-d...
# 28  {'url': 'https://api.github.com/repos/pandas-d...
# 29  {'url': 'https://api.github.com/repos/pandas-d...
#
#                                          timeline_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#    performed_via_github_app state_reason
# 0                       NaN          NaN
# 1                       NaN          NaN
# 2                       NaN          NaN
# 3                       NaN          NaN
# 4                       NaN          NaN
# 5                       NaN          NaN
# 6                       NaN          NaN
# 7                       NaN          NaN
# 8                       NaN          NaN
# 9                       NaN          NaN
# 10                      NaN          NaN
# 11                      NaN          NaN
# 12                      NaN          NaN
# 13                      NaN          NaN
# 14                      NaN          NaN
# 15                      NaN          NaN
# 16                      NaN          NaN
# 17                      NaN          NaN
# 18                      NaN          NaN
# 19                      NaN          NaN
# 20                      NaN          NaN
# 21                      NaN          NaN
# 22                      NaN          NaN
# 23                      NaN          NaN
# 24                      NaN          NaN
# 25                      NaN          NaN
# 26                      NaN          NaN
# 27                      NaN          NaN
# 28                      NaN          NaN
# 29                      NaN          NaN
#
# [30 rows x 30 columns]

# %%
js.columns
# Out:
# Index(['url', 'repository_url', 'labels_url', 'comments_url', 'events_url',
#        'html_url', 'id', 'node_id', 'number', 'title', 'user', 'labels',
#        'state', 'locked', 'assignee', 'assignees', 'milestone', 'comments',
#        'created_at', 'updated_at', 'closed_at', 'author_association',
#        'active_lock_reason', 'draft', 'pull_request', 'body', 'reactions',
#        'timeline_url', 'performed_via_github_app', 'state_reason'],
#       dtype='object')

# %%
js['user']
# Out:
# 0     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 1     {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 2     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 3     {'login': 'tehunter', 'id': 7980666, 'node_id'...
# 4     {'login': 'ryanbaekr', 'id': 76887060, 'node_i...
# 5     {'login': 'Th3nn3ss', 'id': 25160953, 'node_id...
# 6     {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 7     {'login': 'fyrestone', 'id': 6308809, 'node_id...
# 8     {'login': 'PrimozGodec', 'id': 6421558, 'node_...
# 9     {'login': 'marekro', 'id': 43476190, 'node_id'...
# 10    {'login': 'mattiatantardini', 'id': 66005981, ...
# 11    {'login': 'adrien-berchet', 'id': 11536226, 'n...
# 12    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 13    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 14    {'login': 'bashtage', 'id': 5585221, 'node_id'...
# 15    {'login': 'rhshadrach', 'id': 45562402, 'node_...
# 16    {'login': 'gsheni', 'id': 8726321, 'node_id': ...
# 17    {'login': 'gsheni', 'id': 8726321, 'node_id': ...
# 18    {'login': 'derHeinzer', 'id': 43210452, 'node_...
# 19    {'login': 'datapythonista', 'id': 10058240, 'n...
# 20    {'login': 'NSH531', 'id': 5903577, 'node_id': ...
# 21    {'login': 'ojdo', 'id': 3525666, 'node_id': 'M...
# 22    {'login': 'Th3nn3ss', 'id': 25160953, 'node_id...
# 23    {'login': 'gsheni', 'id': 8726321, 'node_id': ...
# 24    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 25    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 26    {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 27    {'login': 'aulemahal', 'id': 20629530, 'node_i...
# 28    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 29    {'login': 'phofl', 'id': 61934744, 'node_id': ...
# Name: user, dtype: object

# %%
a
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# 1          Petal   natural     microfiber         NaN     ruffles
# 2           full   natural       polyster         NaN         NaN
# 3           full   natural           silk     chiffon  embroidary
# 4      butterfly   natural  chiffonfabric     chiffon         bow
# ..           ...       ...            ...         ...         ...
# 495         full   natural       polyster         NaN         NaN
# 496         full    empire         cotton         NaN         NaN
# 497         full    empire         cotton         NaN        lace
# 498    sleevless    empire           silk  broadcloth    applique
# 499        short    empire         cotton    Corduroy        lace
#
#     Pattern Type  Recommendation
# 0         animal               1
# 1         animal               0
# 2          print               0
# 3          print               1
# 4            dot               0
# ..           ...             ...
# 495        solid               1
# 496          NaN               0
# 497        solid               1
# 498        print               1
# 499        solid               0
#
# [500 rows x 14 columns]

# %%
a.to_json('test.json')

# %%
pwd
# Out:
# 'C:\\Users\\HP'

# %%
# in pandas we can convert any file to another type of file#

# %%
a.to_csv('T1.csv',sep='#')

# %%
pwd
# Out:
# 'C:\\Users\\HP'

# %%
ysql:
    1.Create a table attribute daset and dress dataset
    2.Do a bulk load for these two table for respective dataset
    3.read these dataset in pandas as a dataframe
    4.convert attribute dataset in json format
    5.Store this dataset into mongodb
    6.in sql task try to perform left join operation with attribute and dress data sets on clumns
    7.Write a sql query to fcind out how many unique dress based on drtess id
    8.try to find out how many dresses having recomendation zero
    9.try to find out third highest most selling dress id
    10.
# Out:
#   Input In [82]
#     Mysql:
#           ^
# SyntaxError: invalid syntax

# %%
a
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# 1          Petal   natural     microfiber         NaN     ruffles
# 2           full   natural       polyster         NaN         NaN
# 3           full   natural           silk     chiffon  embroidary
# 4      butterfly   natural  chiffonfabric     chiffon         bow
# ..           ...       ...            ...         ...         ...
# 495         full   natural       polyster         NaN         NaN
# 496         full    empire         cotton         NaN         NaN
# 497         full    empire         cotton         NaN        lace
# 498    sleevless    empire           silk  broadcloth    applique
# 499        short    empire         cotton    Corduroy        lace
#
#     Pattern Type  Recommendation
# 0         animal               1
# 1         animal               0
# 2          print               0
# 3          print               1
# 4            dot               0
# ..           ...             ...
# 495        solid               1
# 496          NaN               0
# 497        solid               1
# 498        print               1
# 499        solid               0
#
# [500 rows x 14 columns]

# %%
type(a['Style'])
# Out:
# pandas.core.series.Series

# %%
a.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# waiseline          object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# dtype: object

# %%
a['Dress_ID','Price']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Dress_ID', 'Price')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [86], in <cell line: 1>()
# ----> 1 a['Dress_ID','Price']
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ('Dress_ID', 'Price')

# %%
l1=a[['Dress_ID','Price']]

# %%
l1
# Out:
#        Dress_ID    Price
# 0    1006032852      Low
# 1    1212192089      Low
# 2    1190380701     High
# 3     966005983  Average
# 4     876339541      Low
# ..          ...      ...
# 495   713391965      Low
# 496   722565148      Low
# 497   532874347  Average
# 498   655464934  Average
# 499   919930954      Low
#
# [500 rows x 2 columns]

# %%
type(l1)
# Out:
# pandas.core.frame.DataFrame

# %%
l2=a[['Price']]

# %%
l2
# Out:
#        Price
# 0        Low
# 1        Low
# 2       High
# 3    Average
# 4        Low
# ..       ...
# 495      Low
# 496      Low
# 497  Average
# 498  Average
# 499      Low
#
# [500 rows x 1 columns]

# %%
type(l2)
# Out:
# pandas.core.frame.DataFrame

# %%
a.describe()
# Out:
#            Dress_ID      Rating  Recommendation
# count  5.000000e+02  500.000000      500.000000
# mean   9.055417e+08    3.528600        0.420000
# std    1.736190e+08    2.005364        0.494053
# min    4.442820e+08    0.000000        0.000000
# 25%    7.673164e+08    3.700000        0.000000
# 50%    9.083296e+08    4.600000        0.000000
# 75%    1.039534e+09    4.800000        1.000000
# max    1.253973e+09    5.000000        1.000000

# %%
type(a)
# Out:
# pandas.core.frame.DataFrame

# %%
p=a[a.dtypes[a.dtypes=='float64'].index]

# %%
p
# Out:
#      Rating
# 0       4.6
# 1       0.0
# 2       0.0
# 3       4.6
# 4       4.5
# ..      ...
# 495     4.7
# 496     4.3
# 497     4.7
# 498     4.6
# 499     4.4
#
# [500 rows x 1 columns]

# %%
p.describe()
# Out:
#            Rating
# count  500.000000
# mean     3.528600
# std      2.005364
# min      0.000000
# 25%      3.700000
# 50%      4.600000
# 75%      4.800000
# max      5.000000

# %%
q=a[a.dtypes[a.dtypes=='object'].index]

# %%
q
# Out:
#        Style    Price  Size  Season   NeckLine SleeveLength waiseline  \
# 0       Sexy      Low     M  Summer     o-neck    sleevless    empire
# 1     Casual      Low     L  Summer     o-neck        Petal   natural
# 2    vintage     High     L  Automn     o-neck         full   natural
# 3      Brief  Average     L  Spring     o-neck         full   natural
# 4       cute      Low     M  Summer     o-neck    butterfly   natural
# ..       ...      ...   ...     ...        ...          ...       ...
# 495   Casual      Low     M  Spring     o-neck         full   natural
# 496     Sexy      Low  free  Summer     o-neck         full    empire
# 497   Casual  Average     M  Summer     v-neck         full    empire
# 498   Casual  Average     L  winter  boat-neck    sleevless    empire
# 499   Casual      Low  free  Summer     v-neck        short    empire
#
#           Material  FabricType  Decoration Pattern Type
# 0              NaN     chiffon     ruffles       animal
# 1       microfiber         NaN     ruffles       animal
# 2         polyster         NaN         NaN        print
# 3             silk     chiffon  embroidary        print
# 4    chiffonfabric     chiffon         bow          dot
# ..             ...         ...         ...          ...
# 495       polyster         NaN         NaN        solid
# 496         cotton         NaN         NaN          NaN
# 497         cotton         NaN        lace        solid
# 498           silk  broadcloth    applique        print
# 499         cotton    Corduroy        lace        solid
#
# [500 rows x 11 columns]

# %%
q.describe()
# Out:
#          Style    Price Size  Season NeckLine SleeveLength waiseline Material  \
# count      500      498  500     498      497          498       413      372
# unique      13        7    7       8       16           17         4       23
# top     Casual  Average    M  Summer   o-neck    sleevless   natural   cotton
# freq       232      252  177     159      271          223       304      152
#
#        FabricType Decoration Pattern Type
# count         234        264          391
# unique         22         24           14
# top       chiffon       lace        solid
# freq          135         70          203

# %%
a['Style'][1:5]
# Out:
# 1     Casual
# 2    vintage
# 3      Brief
# 4       cute
# Name: Style, dtype: object

# %%
a['pavan']='kumar'

# %%
a['pavan']
# Out:
# 0      kumar
# 1      kumar
# 2      kumar
# 3      kumar
# 4      kumar
#        ...
# 495    kumar
# 496    kumar
# 497    kumar
# 498    kumar
# 499    kumar
# Name: pavan, Length: 500, dtype: object

# %%
a.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation', 'pavan'],
#       dtype='object')

# %%
a['Style'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 495    False
# 496    False
# 497    False
# 498    False
# 499    False
# Name: Style, Length: 500, dtype: bool

# %%
a['pavan'][1:10].isnull()
# Out:
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: pavan, dtype: bool

# %%
d['A'][1:5].isnull()
# Out:
# 1    False
# 2    False
# 3    False
# 4    False
# Name: A, dtype: bool

# %%
ds=pd.read_excel(r'C:\Users\HP\Downloads\Dress sales.xlsx')

# %%
ds
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# 2                      7                    8                    8
# 3                   1455                 1507                 1621
# 4                   1396                 1432                 1559
# ..                   ...                  ...                  ...
# 495                  560                  554                  544
# 496                  875                  866                  861
# 497                  734                  728                  726
# 498                  254                  259                  261
# 499                  538                  545                  558
#
#      2013-10-09 00:00:00 2013-12-09 00:00:00 14/9/2013  ... 24/9/2013  \
# 0                   2930                3119      3204  ...      3554
# 1                   1164                1558      1756  ...      2710
# 2                      9                  10        10  ...        11
# 3                   1637                1723      1746  ...      1878
# 4                   1570                1638      1655  ...      2032
# ..                   ...                 ...       ...  ...       ...
# 495                  537                 525       519  ...       400
# 496                  854                 850       844  ...       859
# 497                  715                 694       690  ...       616
# 498                  263                 268       270  ...       257
# 499                  563                 578       585  ...       628
#
#     26/9/2013 28/9/2013 30/9/2013  2013-02-10 00:00:00  2013-04-10 00:00:00  \
# 0      3624.0      3706    3746.0               3795.0               3832.0
# 1      2942.0      3258    3354.0               3475.0               3654.0
# 2        11.0        11      11.0                 11.0                 11.0
# 3      1892.0      1914    1924.0               1929.0               1941.0
# 4      2156.0      2252    2312.0               2387.0               2459.0
# ..        ...       ...       ...                  ...                  ...
# 495     388.0       360     364.0                372.0                377.0
# 496     866.0       882     888.0                895.0                898.0
# 497     597.0       586     569.0                561.0                555.0
# 498     256.0       255     254.0                253.0                250.0
# 499     632.0       639     645.0                651.0                655.0
#
#      2013-06-10 00:00:00  2010-08-10 00:00:00  2013-10-10 00:00:00  \
# 0                   3897               3923.0               3985.0
# 1                   3911               4024.0               4125.0
# 2                     11                 11.0                 11.0
# 3                   1952               1955.0               1959.0
# 4                   2544               2614.0               2693.0
# ..                   ...                  ...                  ...
# 495                  380                382.0                384.0
# 496                  906                913.0                919.0
# 497                  551                546.0                535.0
# 498                  249                249.0                249.0
# 499                  660                668.0                674.0
#
#      2013-12-10 00:00:00
# 0                   4048
# 1                   4277
# 2                     11
# 3                   1963
# 4                   2736
# ..                   ...
# 495                  285
# 496                  931
# 497                  520
# 498                  248
# 499                  680
#
# [500 rows x 24 columns]

# %%
ds.columns
# Out:
# Index([         'Dress_ID',         '29/8/2013',         '31/8/2013',
#        2013-02-09 00:00:00, 2013-04-09 00:00:00, 2013-06-09 00:00:00,
#        2013-08-09 00:00:00, 2013-10-09 00:00:00, 2013-12-09 00:00:00,
#                '14/9/2013',         '16/9/2013',         '18/9/2013',
#                '20/9/2013',         '22/9/2013',         '24/9/2013',
#                '26/9/2013',         '28/9/2013',         '30/9/2013',
#        2013-02-10 00:00:00, 2013-04-10 00:00:00, 2013-06-10 00:00:00,
#        2010-08-10 00:00:00, 2013-10-10 00:00:00, 2013-12-10 00:00:00],
#       dtype='object')

# %%
a.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation', 'pavan'],
#       dtype='object')

# %%
a[a['Rating']<4.0][0:10]
# Out:
#       Dress_ID     Style    Price  Rating  Size  Season         NeckLine  \
# 1   1212192089    Casual      Low     0.0     L  Summer           o-neck
# 2   1190380701   vintage     High     0.0     L  Automn           o-neck
# 5   1068332458  bohemian      Low     0.0     M  Summer           v-neck
# 6   1220707172    Casual  Average     0.0    XL  Summer           o-neck
# 7   1219677488   Novelty  Average     0.0  free  Automn           o-neck
# 8   1113094204     Flare  Average     0.0  free  Spring           v-neck
# 9    985292672  bohemian      Low     0.0  free  Summer           v-neck
# 11   898481530     Flare  Average     0.0  free  Spring           v-neck
# 15  1162628131    Casual      Low     0.0  free  Winter        boat-neck
# 18   840857118     Brief  Average     0.0     M  Winter  peterpan-collor
#
#     SleeveLength waiseline    Material  FabricType Decoration Pattern Type  \
# 1          Petal   natural  microfiber         NaN    ruffles       animal
# 2           full   natural    polyster         NaN        NaN        print
# 5      sleevless    empire         NaN         NaN        NaN        print
# 6           full       NaN      cotton         NaN        NaN        solid
# 7          short   natural    polyster  broadcloth       lace          NaN
# 8          short    empire      cotton  broadcloth    beading        solid
# 9      sleevless   natural       nylon     chiffon        NaN          NaN
# 11         short       NaN       nylon         NaN        NaN       animal
# 15          full       NaN       other       other       lace          NaN
# 18  threequarter   natural      cotton         NaN        NaN    patchwork
#
#     Recommendation  pavan
# 1                0  kumar
# 2                0  kumar
# 5                0  kumar
# 6                0  kumar
# 7                0  kumar
# 8                1  kumar
# 9                1  kumar
# 11               0  kumar
# 15               0  kumar
# 18               0  kumar

# %%
a[a['Rating']<3.0]['Style'][0:10]
# Out:
# 1       Casual
# 2      vintage
# 5     bohemian
# 6       Casual
# 7      Novelty
# 8        Flare
# 9     bohemian
# 11       Flare
# 15      Casual
# 18       Brief
# Name: Style, dtype: object

# %%
a[(a['Style']=='Casual')&(a['Rating']<3)&(a['Season']=='Summer')]['Size']
# Out:
# 1         L
# 6        XL
# 27        L
# 47        M
# 66     free
# 130       M
# 197    free
# 207       M
# 222       S
# 426    free
# 427    free
# Name: Size, dtype: object

# %%
ds
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2013-02-09 00:00:00  \
# 0    1006032852       2114       2274                 2491
# 1    1212192089        151        275                  570
# 2    1190380701          6          7                    7
# 3     966005983       1005       1128                 1326
# 4     876339541        996       1175                 1304
# ..          ...        ...        ...                  ...
# 495   713391965          0          0                    0
# 496   722565148          0          0                    0
# 497   532874347          0          0                    0
# 498   655464934          0          0                    0
# 499   919930954          0          0                    0
#
#      2013-04-09 00:00:00  2013-06-09 00:00:00  2013-08-09 00:00:00  \
# 0                   2660                 2727                 2887
# 1                    750                  813                 1066
# 2                      7                    8                    8
# 3                   1455                 1507                 1621
# 4                   1396                 1432                 1559
# ..                   ...                  ...                  ...
# 495                  560                  554                  544
# 496                  875                  866                  861
# 497                  734                  728                  726
# 498                  254                  259                  261
# 499                  538                  545                  558
#
#      2013-10-09 00:00:00 2013-12-09 00:00:00 14/9/2013  ... 24/9/2013  \
# 0                   2930                3119      3204  ...      3554
# 1                   1164                1558      1756  ...      2710
# 2                      9                  10        10  ...        11
# 3                   1637                1723      1746  ...      1878
# 4                   1570                1638      1655  ...      2032
# ..                   ...                 ...       ...  ...       ...
# 495                  537                 525       519  ...       400
# 496                  854                 850       844  ...       859
# 497                  715                 694       690  ...       616
# 498                  263                 268       270  ...       257
# 499                  563                 578       585  ...       628
#
#     26/9/2013 28/9/2013 30/9/2013  2013-02-10 00:00:00  2013-04-10 00:00:00  \
# 0      3624.0      3706    3746.0               3795.0               3832.0
# 1      2942.0      3258    3354.0               3475.0               3654.0
# 2        11.0        11      11.0                 11.0                 11.0
# 3      1892.0      1914    1924.0               1929.0               1941.0
# 4      2156.0      2252    2312.0               2387.0               2459.0
# ..        ...       ...       ...                  ...                  ...
# 495     388.0       360     364.0                372.0                377.0
# 496     866.0       882     888.0                895.0                898.0
# 497     597.0       586     569.0                561.0                555.0
# 498     256.0       255     254.0                253.0                250.0
# 499     632.0       639     645.0                651.0                655.0
#
#      2013-06-10 00:00:00  2010-08-10 00:00:00  2013-10-10 00:00:00  \
# 0                   3897               3923.0               3985.0
# 1                   3911               4024.0               4125.0
# 2                     11                 11.0                 11.0
# 3                   1952               1955.0               1959.0
# 4                   2544               2614.0               2693.0
# ..                   ...                  ...                  ...
# 495                  380                382.0                384.0
# 496                  906                913.0                919.0
# 497                  551                546.0                535.0
# 498                  249                249.0                249.0
# 499                  660                668.0                674.0
#
#      2013-12-10 00:00:00
# 0                   4048
# 1                   4277
# 2                     11
# 3                   1963
# 4                   2736
# ..                   ...
# 495                  285
# 496                  931
# 497                  520
# 498                  248
# 499                  680
#
# [500 rows x 24 columns]

# %%
gh=pd.read_csv(r'https://raw.githubusercontent.com/selva86/datasets/master/df_final.csv')

# %%
gh
# Out:
#         Country  Annual.GDP.Growth        Date  Last_inflation  \
# 0       Albania               2.31  2019-06-19            1.30
# 1       Algeria               1.50  2019-03-19            1.80
# 2        Angola              -0.10  2019-06-19           16.08
# 3     Argentina               0.60  2019-06-19           53.50
# 4       Armenia               6.50  2019-06-19            0.50
# ..          ...                ...         ...             ...
# 157  Uzbekistan               5.80  2019-06-19           14.30
# 158     Vietnam               7.31  2019-09-19            2.24
# 159       Yemen              -2.70  2019-12-18            9.49
# 160      Zambia               3.70  2019-12-18           10.70
# 161    Zimbabwe               4.00  2019-12-18          288.50
#
#     Operating.Region    Scope gdp_cat
# 0             Europe  Include  Medium
# 1             Africa  Include     Low
# 2             Africa  Include     Low
# 3            America  Include     Low
# 4               Asia  Include    High
# ..               ...      ...     ...
# 157             Asia  Include    High
# 158             Asia  Include    High
# 159             Asia  Include     Low
# 160           Africa  Include  Medium
# 161           Africa  Include  Medium
#
# [162 rows x 7 columns]

# %%
gh.columns
# Out:
# Index(['Country', 'Annual.GDP.Growth', 'Date', 'Last_inflation',
#        'Operating.Region', 'Scope', 'gdp_cat'],
#       dtype='object')

# %%
gh.dtypes
# Out:
# Country               object
# Annual.GDP.Growth    float64
# Date                  object
# Last_inflation       float64
# Operating.Region      object
# Scope                 object
# gdp_cat               object
# dtype: object

# %%
# convert date from 'object' to 'datetime64'#

# %%
pd.to_datetime(gh['Date'])
# Out:
# 0     2019-06-19
# 1     2019-03-19
# 2     2019-06-19
# 3     2019-06-19
# 4     2019-06-19
#          ...
# 157   2019-06-19
# 158   2019-09-19
# 159   2019-12-18
# 160   2019-12-18
# 161   2019-12-18
# Name: Date, Length: 162, dtype: datetime64[ns]

# %%
gh['converted date order']=pd.to_datetime(gh['Date'])

# %%
gh.columns
# Out:
# Index(['Country', 'Annual.GDP.Growth', 'Date', 'Last_inflation',
#        'Operating.Region', 'Scope', 'gdp_cat', 'converted date order'],
#       dtype='object')

# %%
gh
# Out:
#         Country  Annual.GDP.Growth        Date  Last_inflation  \
# 0       Albania               2.31  2019-06-19            1.30
# 1       Algeria               1.50  2019-03-19            1.80
# 2        Angola              -0.10  2019-06-19           16.08
# 3     Argentina               0.60  2019-06-19           53.50
# 4       Armenia               6.50  2019-06-19            0.50
# ..          ...                ...         ...             ...
# 157  Uzbekistan               5.80  2019-06-19           14.30
# 158     Vietnam               7.31  2019-09-19            2.24
# 159       Yemen              -2.70  2019-12-18            9.49
# 160      Zambia               3.70  2019-12-18           10.70
# 161    Zimbabwe               4.00  2019-12-18          288.50
#
#     Operating.Region    Scope gdp_cat converted date order
# 0             Europe  Include  Medium           2019-06-19
# 1             Africa  Include     Low           2019-03-19
# 2             Africa  Include     Low           2019-06-19
# 3            America  Include     Low           2019-06-19
# 4               Asia  Include    High           2019-06-19
# ..               ...      ...     ...                  ...
# 157             Asia  Include    High           2019-06-19
# 158             Asia  Include    High           2019-09-19
# 159             Asia  Include     Low           2019-12-18
# 160           Africa  Include  Medium           2019-12-18
# 161           Africa  Include  Medium           2019-12-18
#
# [162 rows x 8 columns]

# %%
gh['order date year']=gh['converted date order'].dt.year

# %%
gh.head()
# Out:
#      Country  Annual.GDP.Growth        Date  Last_inflation Operating.Region  \
# 0    Albania               2.31  2019-06-19            1.30           Europe
# 1    Algeria               1.50  2019-03-19            1.80           Africa
# 2     Angola              -0.10  2019-06-19           16.08           Africa
# 3  Argentina               0.60  2019-06-19           53.50          America
# 4    Armenia               6.50  2019-06-19            0.50             Asia
#
#      Scope gdp_cat converted date order  order date year
# 0  Include  Medium           2019-06-19             2019
# 1  Include     Low           2019-03-19             2019
# 2  Include     Low           2019-06-19             2019
# 3  Include     Low           2019-06-19             2019
# 4  Include    High           2019-06-19             2019

# %%
gh['order date week']=gh['converted date order'].dt.weekofyear
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_10440\2344189050.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   gh['order date week']=gh['converted date order'].dt.weekofyear

# %%
gh.head()
# Out:
#      Country  Annual.GDP.Growth        Date  Last_inflation Operating.Region  \
# 0    Albania               2.31  2019-06-19            1.30           Europe
# 1    Algeria               1.50  2019-03-19            1.80           Africa
# 2     Angola              -0.10  2019-06-19           16.08           Africa
# 3  Argentina               0.60  2019-06-19           53.50          America
# 4    Armenia               6.50  2019-06-19            0.50             Asia
#
#      Scope gdp_cat converted date order  order date year  order date week
# 0  Include  Medium           2019-06-19             2019               25
# 1  Include     Low           2019-03-19             2019               12
# 2  Include     Low           2019-06-19             2019               25
# 3  Include     Low           2019-06-19             2019               25
# 4  Include    High           2019-06-19             2019               25

# %%
gh[(gh['order date year']==2019)&(gh['order date week']>25)].head()
# Out:
#        Country  Annual.GDP.Growth        Date  Last_inflation  \
# 6      Austria                1.5  2019-09-19            1.20
# 8      Bahamas                1.6  2019-12-18            2.90
# 10  Bangladesh                7.9  2019-12-18            5.54
# 11    Barbados               -0.6  2019-12-18            3.20
# 12     Belgium                1.6  2019-09-19            0.48
#
#    Operating.Region    Scope gdp_cat converted date order  order date year  \
# 6            Europe  Include     Low           2019-09-19             2019
# 8           America  Include     Low           2019-12-18             2019
# 10             Asia  Include    High           2019-12-18             2019
# 11          America  Include     Low           2019-12-18             2019
# 12           Europe  Include     Low           2019-09-19             2019
#
#     order date week
# 6                38
# 8                51
# 10               51
# 11               51
# 12               38

# %%
gh[gh['Annual.GDP.Growth']==max(gh['Annual.GDP.Growth'])]['order date week']
# Out:
# 126    25
# Name: order date week, dtype: int64

# %%
gh[122:127]
# Out:
#                    Country  Annual.GDP.Growth        Date  Last_inflation  \
# 122                  Qatar               -1.4  2019-06-19             0.1
# 123  Republic of the Congo                1.9  2019-12-18             1.1
# 124                Romania                4.4  2019-06-19             3.5
# 125                 Russia                0.9  2019-06-19             4.0
# 126                 Rwanda               12.2  2019-06-19             4.6
#
#     Operating.Region    Scope gdp_cat converted date order  order date year  \
# 122             Asia  Include     Low           2019-06-19             2019
# 123           Africa  Include     Low           2019-12-18             2019
# 124           Europe  Include  Medium           2019-06-19             2019
# 125           Europe  Include     Low           2019-06-19             2019
# 126           Africa  Exclude    High           2019-06-19             2019
#
#      order date week
# 122               25
# 123               51
# 124               25
# 125               25
# 126               25

# %%
gh['order date week'].value_counts()
# Out:
# 25    93
# 51    45
# 38    19
# 12     5
# Name: order date week, dtype: int64

# %%
# the above is to get the groups#

# %%
gh.head()
# Out:
#      Country  Annual.GDP.Growth        Date  Last_inflation Operating.Region  \
# 0    Albania               2.31  2019-06-19            1.30           Europe
# 1    Algeria               1.50  2019-03-19            1.80           Africa
# 2     Angola              -0.10  2019-06-19           16.08           Africa
# 3  Argentina               0.60  2019-06-19           53.50          America
# 4    Armenia               6.50  2019-06-19            0.50             Asia
#
#      Scope gdp_cat converted date order  order date year  order date week
# 0  Include  Medium           2019-06-19             2019               25
# 1  Include     Low           2019-03-19             2019               12
# 2  Include     Low           2019-06-19             2019               25
# 3  Include     Low           2019-06-19             2019               25
# 4  Include    High           2019-06-19             2019               25

# %%
gh['new addition']=gh['Annual.GDP.Growth']+gh['Last_inflation']

# %%
gh.head()
# Out:
#      Country  Annual.GDP.Growth        Date  Last_inflation Operating.Region  \
# 0    Albania               2.31  2019-06-19            1.30           Europe
# 1    Algeria               1.50  2019-03-19            1.80           Africa
# 2     Angola              -0.10  2019-06-19           16.08           Africa
# 3  Argentina               0.60  2019-06-19           53.50          America
# 4    Armenia               6.50  2019-06-19            0.50             Asia
#
#      Scope gdp_cat converted date order  order date year  order date week  \
# 0  Include  Medium           2019-06-19             2019               25
# 1  Include     Low           2019-03-19             2019               12
# 2  Include     Low           2019-06-19             2019               25
# 3  Include     Low           2019-06-19             2019               25
# 4  Include    High           2019-06-19             2019               25
#
#    new addition
# 0          3.61
# 1          3.30
# 2         15.98
# 3         54.10
# 4          7.00

# %%
a.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation', 'pavan'],
#       dtype='object')

# %%
a.drop('pavan')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [208], in <cell line: 1>()
# ----> 1 a.drop('pavan')
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['pavan'] not found in axis"

# %%
a.drop('pavan',axis=1).head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
# for deleting perticular column use axis=1 and for a row axis=0)

# %%
a=a.drop('Style',axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [222], in <cell line: 1>()
# ----> 1 a=a.drop('Style',axis=1,inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Style'] not found in axis"

# %%
# to save all changes again assign that to same name  #
           #or#
    # use following method#

# %%
a.drop('Season',axis=1,inplace=True)

# %%
a.columns
# Out:
# Index(['Dress_ID', 'Price', 'Rating', 'Size', 'NeckLine', 'SleeveLength',
#        'waiseline', 'Material', 'FabricType', 'Decoration', 'Pattern Type',
#        'Recommendation'],
#       dtype='object')

# %%
a.loc[[2,3]]
# Out:
#      Dress_ID    Price  Rating Size NeckLine SleeveLength waiseline  Material  \
# 2  1190380701     High     0.0    L   o-neck         full   natural  polyster
# 3   966005983  Average     4.6    L   o-neck         full   natural      silk
#
#   FabricType  Decoration Pattern Type  Recommendation
# 2        NaN         NaN        print               0
# 3    chiffon  embroidary        print               1

# %%
a[2:4]
# Out:
#      Dress_ID    Price  Rating Size NeckLine SleeveLength waiseline  Material  \
# 2  1190380701     High     0.0    L   o-neck         full   natural  polyster
# 3   966005983  Average     4.6    L   o-neck         full   natural      silk
#
#   FabricType  Decoration Pattern Type  Recommendation
# 2        NaN         NaN        print               0
# 3    chiffon  embroidary        print               1

# %%
a.loc[1:10:1]
# Out:
#      Dress_ID    Price  Rating Size NeckLine SleeveLength waiseline  \
# 1  1212192089      Low     0.0    L   o-neck        Petal   natural
# 2  1190380701     High     0.0    L   o-neck         full   natural
# 3   966005983  Average     4.6    L   o-neck         full   natural
# 4   876339541      Low     4.5    M   o-neck    butterfly   natural
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
gh.loc[1:10:2]
# Out:
#       Country  Annual.GDP.Growth        Date  Last_inflation Operating.Region  \
# 1     Algeria               1.50  2019-03-19             1.8           Africa
# 3   Argentina               0.60  2019-06-19            53.5          America
# 5   Australia               1.40  2019-06-19             1.7        Australia
# 7  Azerbaijan               2.40  2019-06-19             2.6             Asia
# 9     Bahrain               0.84  2019-06-19             1.2             Asia
#
#      Scope gdp_cat converted date order  order date year  order date week  \
# 1  Include     Low           2019-03-19             2019               12
# 3  Include     Low           2019-06-19             2019               25
# 5  Include     Low           2019-06-19             2019               25
# 7  Include  Medium           2019-06-19             2019               25
# 9  Include     Low           2019-06-19             2019               25
#
#    new addition
# 1          3.30
# 3         54.10
# 5          3.10
# 7          5.00
# 9          2.04

# %%
gh.loc[5:10]
# Out:
#        Country  Annual.GDP.Growth        Date  Last_inflation  \
# 5    Australia               1.40  2019-06-19            1.70
# 6      Austria               1.50  2019-09-19            1.20
# 7   Azerbaijan               2.40  2019-06-19            2.60
# 8      Bahamas               1.60  2019-12-18            2.90
# 9      Bahrain               0.84  2019-06-19            1.20
# 10  Bangladesh               7.90  2019-12-18            5.54
#
#    Operating.Region    Scope gdp_cat converted date order  order date year  \
# 5         Australia  Include     Low           2019-06-19             2019
# 6            Europe  Include     Low           2019-09-19             2019
# 7              Asia  Include  Medium           2019-06-19             2019
# 8           America  Include     Low           2019-12-18             2019
# 9              Asia  Include     Low           2019-06-19             2019
# 10             Asia  Include    High           2019-12-18             2019
#
#     order date week  new addition
# 5                25          3.10
# 6                38          2.70
# 7                25          5.00
# 8                51          4.50
# 9                25          2.04
# 10               51         13.44

# %%
gh.loc[0:4,['Country','Date']]
# Out:
#      Country        Date
# 0    Albania  2019-06-19
# 1    Algeria  2019-03-19
# 2     Angola  2019-06-19
# 3  Argentina  2019-06-19
# 4    Armenia  2019-06-19

# %%
gh.iloc[0:5,0:6:2]
# Out:
#      Country        Date Operating.Region
# 0    Albania  2019-06-19           Europe
# 1    Algeria  2019-03-19           Africa
# 2     Angola  2019-06-19           Africa
# 3  Argentina  2019-06-19          America
# 4    Armenia  2019-06-19             Asia

# %%
# iloc is similar to slicing#

# %%
gh.iloc[0:4,0:3:2]
# Out:
#      Country        Date
# 0    Albania  2019-06-19
# 1    Algeria  2019-03-19
# 2     Angola  2019-06-19
# 3  Argentina  2019-06-19

# %%
gh.head()
# Out:
#      Country  Annual.GDP.Growth        Date  Last_inflation Operating.Region  \
# 0    Albania               2.31  2019-06-19            1.30           Europe
# 1    Algeria               1.50  2019-03-19            1.80           Africa
# 2     Angola              -0.10  2019-06-19           16.08           Africa
# 3  Argentina               0.60  2019-06-19           53.50          America
# 4    Armenia               6.50  2019-06-19            0.50             Asia
#
#      Scope gdp_cat converted date order  order date year  order date week  \
# 0  Include  Medium           2019-06-19             2019               25
# 1  Include     Low           2019-03-19             2019               12
# 2  Include     Low           2019-06-19             2019               25
# 3  Include     Low           2019-06-19             2019               25
# 4  Include    High           2019-06-19             2019               25
#
#    new addition
# 0          3.61
# 1          3.30
# 2         15.98
# 3         54.10
# 4          7.00

# %%
gh[gh['Last_inflation']>50.0]
# Out:
#        Country  Annual.GDP.Growth        Date  Last_inflation  \
# 3    Argentina                0.6  2019-06-19            53.5
# 140      Sudan                4.1  2019-12-18            53.1
# 161   Zimbabwe                4.0  2019-12-18           288.5
#
#     Operating.Region    Scope gdp_cat converted date order  order date year  \
# 3            America  Include     Low           2019-06-19             2019
# 140           Africa  Include  Medium           2019-12-18             2019
# 161           Africa  Include  Medium           2019-12-18             2019
#
#      order date week  new addition
# 3                 25          54.1
# 140               51          57.2
# 161               51         292.5

# %%
gh1=gh[(gh['Last_inflation']<1.0)|(gh['Last_inflation']>50.0)]

# %%
gh1
# Out:
#                     Country  Annual.GDP.Growth        Date  Last_inflation  \
# 3                 Argentina               0.60  2019-06-19           53.50
# 4                   Armenia               6.50  2019-06-19            0.50
# 12                  Belgium               1.60  2019-09-19            0.48
# 13                   Belize              -0.80  2019-06-19           -0.70
# 14                    Benin               7.20  2019-06-19           -1.70
# 17   Bosnia and Herzegovina               2.60  2019-06-19            0.30
# 20                   Brunei               6.70  2019-06-19           -0.80
# 22             Burkina Faso               6.10  2019-06-19           -5.40
# 27               Cape Verde               6.20  2019-06-19            0.70
# 29                     Chad               1.50  2019-12-18           -2.10
# 36                  Croatia               2.40  2019-06-19            0.80
# 38                   Cyprus               3.20  2019-06-19           -0.90
# 40                  Denmark               2.60  2019-06-19            0.50
# 42                  Ecuador               0.30  2019-06-19           -0.07
# 44              El Salvador               1.80  2019-06-19           -0.68
# 48                Euro Area               1.10  2019-09-19            0.70
# 50                     Fiji               4.20  2019-12-18            0.40
# 51                  Finland               1.20  2019-06-19            0.90
# 52                   France               1.30  2019-09-19            0.70
# 58                   Greece               1.90  2019-06-19           -0.10
# 61            Guinea Bissau               5.10  2019-06-19           -0.30
# 71                     Iraq              -1.00  2019-12-18           -0.30
# 72                  Ireland               5.80  2019-06-19            0.90
# 73                   Israel               3.20  2019-06-19            0.30
# 74                    Italy               0.30  2019-09-19            0.30
# 75              Ivory Coast               7.40  2019-06-19            0.50
# 77                    Japan               1.00  2019-06-19            0.20
# 78                   Jordan               1.80  2019-06-19           -0.30
# 88                    Libya              10.90  2019-12-18           -6.50
# 95                 Maldives               7.60  2019-12-18            0.90
# 96                     Mali               4.90  2019-06-19           -2.20
# 103                 Morocco               2.50  2019-06-19            0.30
# 109           New Caledonia               1.00  2019-12-18            0.20
# 111                   Niger               6.40  2019-06-19           -3.60
# 114                    Oman              12.00  2019-12-18            0.00
# 119             Philippines               5.50  2019-06-19            0.90
# 121                Portugal               1.80  2019-06-19            0.00
# 122                   Qatar              -1.40  2019-06-19            0.10
# 128            Saudi Arabia               0.50  2019-06-19           -0.70
# 129                 Senegal               5.50  2019-06-19            0.70
# 133               Singapore               0.10  2019-09-19            0.50
# 137             South Korea               2.00  2019-09-19            0.00
# 138                   Spain               2.00  2019-09-19            0.10
# 140                   Sudan               4.10  2019-12-18           53.10
# 144             Switzerland               0.20  2019-06-19           -0.30
# 145                  Taiwan               2.91  2019-09-19            0.43
# 148                Thailand               2.30  2019-06-19            0.11
# 149                    Togo               5.00  2019-06-19           -0.30
# 154    United Arab Emirates               2.20  2019-03-19           -2.00
# 161                Zimbabwe               4.00  2019-12-18          288.50
#
#     Operating.Region    Scope gdp_cat converted date order  order date year  \
# 3            America  Include     Low           2019-06-19             2019
# 4               Asia  Include    High           2019-06-19             2019
# 12            Europe  Include     Low           2019-09-19             2019
# 13           America  Include     Low           2019-06-19             2019
# 14            Africa  Include    High           2019-06-19             2019
# 17            Europe  Include  Medium           2019-06-19             2019
# 20              Asia  Include    High           2019-06-19             2019
# 22            Africa  Include    High           2019-06-19             2019
# 27            Africa  Include    High           2019-06-19             2019
# 29            Africa  Include     Low           2019-12-18             2019
# 36            Europe  Include  Medium           2019-06-19             2019
# 38            Europe  Include  Medium           2019-06-19             2019
# 40            Europe  Include  Medium           2019-06-19             2019
# 42           America  Include     Low           2019-06-19             2019
# 44           America  Include     Low           2019-06-19             2019
# 48            Europe  Include     Low           2019-09-19             2019
# 50         Australia  Include  Medium           2019-12-18             2019
# 51            Europe  Include     Low           2019-06-19             2019
# 52            Europe  Include     Low           2019-09-19             2019
# 58            Europe  Include     Low           2019-06-19             2019
# 61            Africa  Include    High           2019-06-19             2019
# 71              Asia  Include     Low           2019-12-18             2019
# 72            Europe  Include    High           2019-06-19             2019
# 73              Asia  Include  Medium           2019-06-19             2019
# 74            Europe  Include     Low           2019-09-19             2019
# 75            Africa  Include    High           2019-06-19             2019
# 77              Asia  Include     Low           2019-06-19             2019
# 78              Asia  Include     Low           2019-06-19             2019
# 88            Africa  Exclude    High           2019-12-18             2019
# 95              Asia  Include    High           2019-12-18             2019
# 96            Africa  Include  Medium           2019-06-19             2019
# 103           Africa  Include  Medium           2019-06-19             2019
# 109        Australia  Include     Low           2019-12-18             2019
# 111           Africa  Include    High           2019-06-19             2019
# 114             Asia  Include    High           2019-12-18             2019
# 119             Asia  Include    High           2019-06-19             2019
# 121           Europe  Include     Low           2019-06-19             2019
# 122             Asia  Include     Low           2019-06-19             2019
# 128             Asia  Include     Low           2019-06-19             2019
# 129           Africa  Include    High           2019-06-19             2019
# 133             Asia  Include     Low           2019-09-19             2019
# 137             Asia  Include  Medium           2019-09-19             2019
# 138           Europe  Include  Medium           2019-09-19             2019
# 140           Africa  Include  Medium           2019-12-18             2019
# 144           Europe  Include     Low           2019-06-19             2019
# 145             Asia  Include  Medium           2019-09-19             2019
# 148             Asia  Include  Medium           2019-06-19             2019
# 149           Africa  Include  Medium           2019-06-19             2019
# 154             Asia  Include  Medium           2019-03-19             2019
# 161           Africa  Include  Medium           2019-12-18             2019
#
#      order date week  new addition
# 3                 25         54.10
# 4                 25          7.00
# 12                38          2.08
# 13                25         -1.50
# 14                25          5.50
# 17                25          2.90
# 20                25          5.90
# 22                25          0.70
# 27                25          6.90
# 29                51         -0.60
# 36                25          3.20
# 38                25          2.30
# 40                25          3.10
# 42                25          0.23
# 44                25          1.12
# 48                38          1.80
# 50                51          4.60
# 51                25          2.10
# 52                38          2.00
# 58                25          1.80
# 61                25          4.80
# 71                51         -1.30
# 72                25          6.70
# 73                25          3.50
# 74                38          0.60
# 75                25          7.90
# 77                25          1.20
# 78                25          1.50
# 88                51          4.40
# 95                51          8.50
# 96                25          2.70
# 103               25          2.80
# 109               51          1.20
# 111               25          2.80
# 114               51         12.00
# 119               25          6.40
# 121               25          1.80
# 122               25         -1.30
# 128               25         -0.20
# 129               25          6.20
# 133               38          0.60
# 137               38          2.00
# 138               38          2.10
# 140               51         57.20
# 144               25         -0.10
# 145               38          3.34
# 148               25          2.41
# 149               25          4.70
# 154               12          0.20
# 161               51        292.50

# %%
gh1.dropna(axis=0)
# Out:
#                     Country  Annual.GDP.Growth        Date  Last_inflation  \
# 3                 Argentina               0.60  2019-06-19           53.50
# 4                   Armenia               6.50  2019-06-19            0.50
# 12                  Belgium               1.60  2019-09-19            0.48
# 13                   Belize              -0.80  2019-06-19           -0.70
# 14                    Benin               7.20  2019-06-19           -1.70
# 17   Bosnia and Herzegovina               2.60  2019-06-19            0.30
# 20                   Brunei               6.70  2019-06-19           -0.80
# 22             Burkina Faso               6.10  2019-06-19           -5.40
# 27               Cape Verde               6.20  2019-06-19            0.70
# 29                     Chad               1.50  2019-12-18           -2.10
# 36                  Croatia               2.40  2019-06-19            0.80
# 38                   Cyprus               3.20  2019-06-19           -0.90
# 40                  Denmark               2.60  2019-06-19            0.50
# 42                  Ecuador               0.30  2019-06-19           -0.07
# 44              El Salvador               1.80  2019-06-19           -0.68
# 48                Euro Area               1.10  2019-09-19            0.70
# 50                     Fiji               4.20  2019-12-18            0.40
# 51                  Finland               1.20  2019-06-19            0.90
# 52                   France               1.30  2019-09-19            0.70
# 58                   Greece               1.90  2019-06-19           -0.10
# 61            Guinea Bissau               5.10  2019-06-19           -0.30
# 71                     Iraq              -1.00  2019-12-18           -0.30
# 72                  Ireland               5.80  2019-06-19            0.90
# 73                   Israel               3.20  2019-06-19            0.30
# 74                    Italy               0.30  2019-09-19            0.30
# 75              Ivory Coast               7.40  2019-06-19            0.50
# 77                    Japan               1.00  2019-06-19            0.20
# 78                   Jordan               1.80  2019-06-19           -0.30
# 88                    Libya              10.90  2019-12-18           -6.50
# 95                 Maldives               7.60  2019-12-18            0.90
# 96                     Mali               4.90  2019-06-19           -2.20
# 103                 Morocco               2.50  2019-06-19            0.30
# 109           New Caledonia               1.00  2019-12-18            0.20
# 111                   Niger               6.40  2019-06-19           -3.60
# 114                    Oman              12.00  2019-12-18            0.00
# 119             Philippines               5.50  2019-06-19            0.90
# 121                Portugal               1.80  2019-06-19            0.00
# 122                   Qatar              -1.40  2019-06-19            0.10
# 128            Saudi Arabia               0.50  2019-06-19           -0.70
# 129                 Senegal               5.50  2019-06-19            0.70
# 133               Singapore               0.10  2019-09-19            0.50
# 137             South Korea               2.00  2019-09-19            0.00
# 138                   Spain               2.00  2019-09-19            0.10
# 140                   Sudan               4.10  2019-12-18           53.10
# 144             Switzerland               0.20  2019-06-19           -0.30
# 145                  Taiwan               2.91  2019-09-19            0.43
# 148                Thailand               2.30  2019-06-19            0.11
# 149                    Togo               5.00  2019-06-19           -0.30
# 154    United Arab Emirates               2.20  2019-03-19           -2.00
# 161                Zimbabwe               4.00  2019-12-18          288.50
#
#     Operating.Region    Scope gdp_cat converted date order  order date year  \
# 3            America  Include     Low           2019-06-19             2019
# 4               Asia  Include    High           2019-06-19             2019
# 12            Europe  Include     Low           2019-09-19             2019
# 13           America  Include     Low           2019-06-19             2019
# 14            Africa  Include    High           2019-06-19             2019
# 17            Europe  Include  Medium           2019-06-19             2019
# 20              Asia  Include    High           2019-06-19             2019
# 22            Africa  Include    High           2019-06-19             2019
# 27            Africa  Include    High           2019-06-19             2019
# 29            Africa  Include     Low           2019-12-18             2019
# 36            Europe  Include  Medium           2019-06-19             2019
# 38            Europe  Include  Medium           2019-06-19             2019
# 40            Europe  Include  Medium           2019-06-19             2019
# 42           America  Include     Low           2019-06-19             2019
# 44           America  Include     Low           2019-06-19             2019
# 48            Europe  Include     Low           2019-09-19             2019
# 50         Australia  Include  Medium           2019-12-18             2019
# 51            Europe  Include     Low           2019-06-19             2019
# 52            Europe  Include     Low           2019-09-19             2019
# 58            Europe  Include     Low           2019-06-19             2019
# 61            Africa  Include    High           2019-06-19             2019
# 71              Asia  Include     Low           2019-12-18             2019
# 72            Europe  Include    High           2019-06-19             2019
# 73              Asia  Include  Medium           2019-06-19             2019
# 74            Europe  Include     Low           2019-09-19             2019
# 75            Africa  Include    High           2019-06-19             2019
# 77              Asia  Include     Low           2019-06-19             2019
# 78              Asia  Include     Low           2019-06-19             2019
# 88            Africa  Exclude    High           2019-12-18             2019
# 95              Asia  Include    High           2019-12-18             2019
# 96            Africa  Include  Medium           2019-06-19             2019
# 103           Africa  Include  Medium           2019-06-19             2019
# 109        Australia  Include     Low           2019-12-18             2019
# 111           Africa  Include    High           2019-06-19             2019
# 114             Asia  Include    High           2019-12-18             2019
# 119             Asia  Include    High           2019-06-19             2019
# 121           Europe  Include     Low           2019-06-19             2019
# 122             Asia  Include     Low           2019-06-19             2019
# 128             Asia  Include     Low           2019-06-19             2019
# 129           Africa  Include    High           2019-06-19             2019
# 133             Asia  Include     Low           2019-09-19             2019
# 137             Asia  Include  Medium           2019-09-19             2019
# 138           Europe  Include  Medium           2019-09-19             2019
# 140           Africa  Include  Medium           2019-12-18             2019
# 144           Europe  Include     Low           2019-06-19             2019
# 145             Asia  Include  Medium           2019-09-19             2019
# 148             Asia  Include  Medium           2019-06-19             2019
# 149           Africa  Include  Medium           2019-06-19             2019
# 154             Asia  Include  Medium           2019-03-19             2019
# 161           Africa  Include  Medium           2019-12-18             2019
#
#      order date week  new addition
# 3                 25         54.10
# 4                 25          7.00
# 12                38          2.08
# 13                25         -1.50
# 14                25          5.50
# 17                25          2.90
# 20                25          5.90
# 22                25          0.70
# 27                25          6.90
# 29                51         -0.60
# 36                25          3.20
# 38                25          2.30
# 40                25          3.10
# 42                25          0.23
# 44                25          1.12
# 48                38          1.80
# 50                51          4.60
# 51                25          2.10
# 52                38          2.00
# 58                25          1.80
# 61                25          4.80
# 71                51         -1.30
# 72                25          6.70
# 73                25          3.50
# 74                38          0.60
# 75                25          7.90
# 77                25          1.20
# 78                25          1.50
# 88                51          4.40
# 95                51          8.50
# 96                25          2.70
# 103               25          2.80
# 109               51          1.20
# 111               25          2.80
# 114               51         12.00
# 119               25          6.40
# 121               25          1.80
# 122               25         -1.30
# 128               25         -0.20
# 129               25          6.20
# 133               38          0.60
# 137               38          2.00
# 138               38          2.10
# 140               51         57.20
# 144               25         -0.10
# 145               38          3.34
# 148               25          2.41
# 149               25          4.70
# 154               12          0.20
# 161               51        292.50

# %%
gh1.dropna(axis=1)
# Out:
#                     Country  Annual.GDP.Growth        Date  Last_inflation  \
# 3                 Argentina               0.60  2019-06-19           53.50
# 4                   Armenia               6.50  2019-06-19            0.50
# 12                  Belgium               1.60  2019-09-19            0.48
# 13                   Belize              -0.80  2019-06-19           -0.70
# 14                    Benin               7.20  2019-06-19           -1.70
# 17   Bosnia and Herzegovina               2.60  2019-06-19            0.30
# 20                   Brunei               6.70  2019-06-19           -0.80
# 22             Burkina Faso               6.10  2019-06-19           -5.40
# 27               Cape Verde               6.20  2019-06-19            0.70
# 29                     Chad               1.50  2019-12-18           -2.10
# 36                  Croatia               2.40  2019-06-19            0.80
# 38                   Cyprus               3.20  2019-06-19           -0.90
# 40                  Denmark               2.60  2019-06-19            0.50
# 42                  Ecuador               0.30  2019-06-19           -0.07
# 44              El Salvador               1.80  2019-06-19           -0.68
# 48                Euro Area               1.10  2019-09-19            0.70
# 50                     Fiji               4.20  2019-12-18            0.40
# 51                  Finland               1.20  2019-06-19            0.90
# 52                   France               1.30  2019-09-19            0.70
# 58                   Greece               1.90  2019-06-19           -0.10
# 61            Guinea Bissau               5.10  2019-06-19           -0.30
# 71                     Iraq              -1.00  2019-12-18           -0.30
# 72                  Ireland               5.80  2019-06-19            0.90
# 73                   Israel               3.20  2019-06-19            0.30
# 74                    Italy               0.30  2019-09-19            0.30
# 75              Ivory Coast               7.40  2019-06-19            0.50
# 77                    Japan               1.00  2019-06-19            0.20
# 78                   Jordan               1.80  2019-06-19           -0.30
# 88                    Libya              10.90  2019-12-18           -6.50
# 95                 Maldives               7.60  2019-12-18            0.90
# 96                     Mali               4.90  2019-06-19           -2.20
# 103                 Morocco               2.50  2019-06-19            0.30
# 109           New Caledonia               1.00  2019-12-18            0.20
# 111                   Niger               6.40  2019-06-19           -3.60
# 114                    Oman              12.00  2019-12-18            0.00
# 119             Philippines               5.50  2019-06-19            0.90
# 121                Portugal               1.80  2019-06-19            0.00
# 122                   Qatar              -1.40  2019-06-19            0.10
# 128            Saudi Arabia               0.50  2019-06-19           -0.70
# 129                 Senegal               5.50  2019-06-19            0.70
# 133               Singapore               0.10  2019-09-19            0.50
# 137             South Korea               2.00  2019-09-19            0.00
# 138                   Spain               2.00  2019-09-19            0.10
# 140                   Sudan               4.10  2019-12-18           53.10
# 144             Switzerland               0.20  2019-06-19           -0.30
# 145                  Taiwan               2.91  2019-09-19            0.43
# 148                Thailand               2.30  2019-06-19            0.11
# 149                    Togo               5.00  2019-06-19           -0.30
# 154    United Arab Emirates               2.20  2019-03-19           -2.00
# 161                Zimbabwe               4.00  2019-12-18          288.50
#
#     Operating.Region    Scope gdp_cat converted date order  order date year  \
# 3            America  Include     Low           2019-06-19             2019
# 4               Asia  Include    High           2019-06-19             2019
# 12            Europe  Include     Low           2019-09-19             2019
# 13           America  Include     Low           2019-06-19             2019
# 14            Africa  Include    High           2019-06-19             2019
# 17            Europe  Include  Medium           2019-06-19             2019
# 20              Asia  Include    High           2019-06-19             2019
# 22            Africa  Include    High           2019-06-19             2019
# 27            Africa  Include    High           2019-06-19             2019
# 29            Africa  Include     Low           2019-12-18             2019
# 36            Europe  Include  Medium           2019-06-19             2019
# 38            Europe  Include  Medium           2019-06-19             2019
# 40            Europe  Include  Medium           2019-06-19             2019
# 42           America  Include     Low           2019-06-19             2019
# 44           America  Include     Low           2019-06-19             2019
# 48            Europe  Include     Low           2019-09-19             2019
# 50         Australia  Include  Medium           2019-12-18             2019
# 51            Europe  Include     Low           2019-06-19             2019
# 52            Europe  Include     Low           2019-09-19             2019
# 58            Europe  Include     Low           2019-06-19             2019
# 61            Africa  Include    High           2019-06-19             2019
# 71              Asia  Include     Low           2019-12-18             2019
# 72            Europe  Include    High           2019-06-19             2019
# 73              Asia  Include  Medium           2019-06-19             2019
# 74            Europe  Include     Low           2019-09-19             2019
# 75            Africa  Include    High           2019-06-19             2019
# 77              Asia  Include     Low           2019-06-19             2019
# 78              Asia  Include     Low           2019-06-19             2019
# 88            Africa  Exclude    High           2019-12-18             2019
# 95              Asia  Include    High           2019-12-18             2019
# 96            Africa  Include  Medium           2019-06-19             2019
# 103           Africa  Include  Medium           2019-06-19             2019
# 109        Australia  Include     Low           2019-12-18             2019
# 111           Africa  Include    High           2019-06-19             2019
# 114             Asia  Include    High           2019-12-18             2019
# 119             Asia  Include    High           2019-06-19             2019
# 121           Europe  Include     Low           2019-06-19             2019
# 122             Asia  Include     Low           2019-06-19             2019
# 128             Asia  Include     Low           2019-06-19             2019
# 129           Africa  Include    High           2019-06-19             2019
# 133             Asia  Include     Low           2019-09-19             2019
# 137             Asia  Include  Medium           2019-09-19             2019
# 138           Europe  Include  Medium           2019-09-19             2019
# 140           Africa  Include  Medium           2019-12-18             2019
# 144           Europe  Include     Low           2019-06-19             2019
# 145             Asia  Include  Medium           2019-09-19             2019
# 148             Asia  Include  Medium           2019-06-19             2019
# 149           Africa  Include  Medium           2019-06-19             2019
# 154             Asia  Include  Medium           2019-03-19             2019
# 161           Africa  Include  Medium           2019-12-18             2019
#
#      order date week  new addition
# 3                 25         54.10
# 4                 25          7.00
# 12                38          2.08
# 13                25         -1.50
# 14                25          5.50
# 17                25          2.90
# 20                25          5.90
# 22                25          0.70
# 27                25          6.90
# 29                51         -0.60
# 36                25          3.20
# 38                25          2.30
# 40                25          3.10
# 42                25          0.23
# 44                25          1.12
# 48                38          1.80
# 50                51          4.60
# 51                25          2.10
# 52                38          2.00
# 58                25          1.80
# 61                25          4.80
# 71                51         -1.30
# 72                25          6.70
# 73                25          3.50
# 74                38          0.60
# 75                25          7.90
# 77                25          1.20
# 78                25          1.50
# 88                51          4.40
# 95                51          8.50
# 96                25          2.70
# 103               25          2.80
# 109               51          1.20
# 111               25          2.80
# 114               51         12.00
# 119               25          6.40
# 121               25          1.80
# 122               25         -1.30
# 128               25         -0.20
# 129               25          6.20
# 133               38          0.60
# 137               38          2.00
# 138               38          2.10
# 140               51         57.20
# 144               25         -0.10
# 145               38          3.34
# 148               25          2.41
# 149               25          4.70
# 154               12          0.20
# 161               51        292.50

# %%
gh.head()
# Out:
#      Country  Annual.GDP.Growth        Date  Last_inflation Operating.Region  \
# 0    Albania               2.31  2019-06-19            1.30           Europe
# 1    Algeria               1.50  2019-03-19            1.80           Africa
# 2     Angola              -0.10  2019-06-19           16.08           Africa
# 3  Argentina               0.60  2019-06-19           53.50          America
# 4    Armenia               6.50  2019-06-19            0.50             Asia
#
#      Scope gdp_cat converted date order  order date year  order date week  \
# 0  Include  Medium           2019-06-19             2019               25
# 1  Include     Low           2019-03-19             2019               12
# 2  Include     Low           2019-06-19             2019               25
# 3  Include     Low           2019-06-19             2019               25
# 4  Include    High           2019-06-19             2019               25
#
#    new addition
# 0          3.61
# 1          3.30
# 2         15.98
# 3         54.10
# 4          7.00

# %%
gh.drop('Country',axis=1)
# Out:
#      Annual.GDP.Growth        Date  Last_inflation Operating.Region    Scope  \
# 0                 2.31  2019-06-19            1.30           Europe  Include
# 1                 1.50  2019-03-19            1.80           Africa  Include
# 2                -0.10  2019-06-19           16.08           Africa  Include
# 3                 0.60  2019-06-19           53.50          America  Include
# 4                 6.50  2019-06-19            0.50             Asia  Include
# ..                 ...         ...             ...              ...      ...
# 157               5.80  2019-06-19           14.30             Asia  Include
# 158               7.31  2019-09-19            2.24             Asia  Include
# 159              -2.70  2019-12-18            9.49             Asia  Include
# 160               3.70  2019-12-18           10.70           Africa  Include
# 161               4.00  2019-12-18          288.50           Africa  Include
#
#     gdp_cat converted date order  order date year  order date week  \
# 0    Medium           2019-06-19             2019               25
# 1       Low           2019-03-19             2019               12
# 2       Low           2019-06-19             2019               25
# 3       Low           2019-06-19             2019               25
# 4      High           2019-06-19             2019               25
# ..      ...                  ...              ...              ...
# 157    High           2019-06-19             2019               25
# 158    High           2019-09-19             2019               38
# 159     Low           2019-12-18             2019               51
# 160  Medium           2019-12-18             2019               51
# 161  Medium           2019-12-18             2019               51
#
#      new addition
# 0            3.61
# 1            3.30
# 2           15.98
# 3           54.10
# 4            7.00
# ..            ...
# 157         20.10
# 158          9.55
# 159          6.79
# 160         14.40
# 161        292.50
#
# [162 rows x 10 columns]

# %%
gh.drop(1,axis=0)
# Out:
#         Country  Annual.GDP.Growth        Date  Last_inflation  \
# 0       Albania               2.31  2019-06-19            1.30
# 2        Angola              -0.10  2019-06-19           16.08
# 3     Argentina               0.60  2019-06-19           53.50
# 4       Armenia               6.50  2019-06-19            0.50
# 5     Australia               1.40  2019-06-19            1.70
# ..          ...                ...         ...             ...
# 157  Uzbekistan               5.80  2019-06-19           14.30
# 158     Vietnam               7.31  2019-09-19            2.24
# 159       Yemen              -2.70  2019-12-18            9.49
# 160      Zambia               3.70  2019-12-18           10.70
# 161    Zimbabwe               4.00  2019-12-18          288.50
#
#     Operating.Region    Scope gdp_cat converted date order  order date year  \
# 0             Europe  Include  Medium           2019-06-19             2019
# 2             Africa  Include     Low           2019-06-19             2019
# 3            America  Include     Low           2019-06-19             2019
# 4               Asia  Include    High           2019-06-19             2019
# 5          Australia  Include     Low           2019-06-19             2019
# ..               ...      ...     ...                  ...              ...
# 157             Asia  Include    High           2019-06-19             2019
# 158             Asia  Include    High           2019-09-19             2019
# 159             Asia  Include     Low           2019-12-18             2019
# 160           Africa  Include  Medium           2019-12-18             2019
# 161           Africa  Include  Medium           2019-12-18             2019
#
#      order date week  new addition
# 0                 25          3.61
# 2                 25         15.98
# 3                 25         54.10
# 4                 25          7.00
# 5                 25          3.10
# ..               ...           ...
# 157               25         20.10
# 158               38          9.55
# 159               51          6.79
# 160               51         14.40
# 161               51        292.50
#
# [161 rows x 11 columns]

# %%
a.dropna(thresh=5)
# Out:
#      Dress_ID    Price  Rating Size NeckLine SleeveLength waiseline  \
# 0  1006032852      Low     4.6    M   o-neck    sleevless    empire
# 1  1212192089      Low     0.0    L   o-neck        Petal   natural
# 2  1190380701     High     0.0    L   o-neck         full   natural
# 3   966005983  Average     4.6    L   o-neck         full   natural
# 4   876339541      Low     4.5    M   o-neck    butterfly   natural
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
## the above meaning of thresh is if u have less than 5 nan values it will drop those rows

# %%
gh.fillna(value=4)
# Out:
#         Country  Annual.GDP.Growth        Date  Last_inflation  \
# 0       Albania               2.31  2019-06-19            1.30
# 1       Algeria               1.50  2019-03-19            1.80
# 2        Angola              -0.10  2019-06-19           16.08
# 3     Argentina               0.60  2019-06-19           53.50
# 4       Armenia               6.50  2019-06-19            0.50
# ..          ...                ...         ...             ...
# 157  Uzbekistan               5.80  2019-06-19           14.30
# 158     Vietnam               7.31  2019-09-19            2.24
# 159       Yemen              -2.70  2019-12-18            9.49
# 160      Zambia               3.70  2019-12-18           10.70
# 161    Zimbabwe               4.00  2019-12-18          288.50
#
#     Operating.Region    Scope gdp_cat converted date order  order date year  \
# 0             Europe  Include  Medium           2019-06-19             2019
# 1             Africa  Include     Low           2019-03-19             2019
# 2             Africa  Include     Low           2019-06-19             2019
# 3            America  Include     Low           2019-06-19             2019
# 4               Asia  Include    High           2019-06-19             2019
# ..               ...      ...     ...                  ...              ...
# 157             Asia  Include    High           2019-06-19             2019
# 158             Asia  Include    High           2019-09-19             2019
# 159             Asia  Include     Low           2019-12-18             2019
# 160           Africa  Include  Medium           2019-12-18             2019
# 161           Africa  Include  Medium           2019-12-18             2019
#
#      order date week  new addition
# 0                 25          3.61
# 1                 12          3.30
# 2                 25         15.98
# 3                 25         54.10
# 4                 25          7.00
# ..               ...           ...
# 157               25         20.10
# 158               38          9.55
# 159               51          6.79
# 160               51         14.40
# 161               51        292.50
#
# [162 rows x 11 columns]

# %%
a.fillna(value=4)
# Out:
#      Dress_ID    Price  Rating Size NeckLine SleeveLength waiseline  \
# 0  1006032852      Low     4.6    M   o-neck    sleevless    empire
# 1  1212192089      Low     0.0    L   o-neck        Petal   natural
# 2  1190380701     High     0.0    L   o-neck         full   natural
# 3   966005983  Average     4.6    L   o-neck         full   natural
# 4   876339541      Low     4.5    M   o-neck    butterfly   natural
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0              4    chiffon     ruffles       animal               1
# 1     microfiber          4     ruffles       animal               0
# 2       polyster          4           4        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
a.fillna(value=10)
# Out:
#      Dress_ID    Price  Rating Size NeckLine SleeveLength waiseline  \
# 0  1006032852      Low     4.6    M   o-neck    sleevless    empire
# 1  1212192089      Low     0.0    L   o-neck        Petal   natural
# 2  1190380701     High     0.0    L   o-neck         full   natural
# 3   966005983  Average     4.6    L   o-neck         full   natural
# 4   876339541      Low     4.5    M   o-neck    butterfly   natural
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0             10    chiffon     ruffles       animal               1
# 1     microfiber         10     ruffles       animal               0
# 2       polyster         10          10        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
gh.groupby('order date week')['Last_inflation'].mean()
# Out:
# order date week
# 12     1.500000
# 25     3.247634
# 38     1.944737
# 51    12.617333
# Name: Last_inflation, dtype: float64

# %%
# above is group by average of last_inflation weekly$$

# %%
gh.groupby('order date week')['Annual.GDP.Growth'].mean()
# Out:
# order date week
# 12    3.420000
# 25    2.988065
# 38    2.390526
# 51    3.646444
# Name: Annual.GDP.Growth, dtype: float64

# %%
gh.Last_inflation.astype('float64')[1:16]
# Out:
# 1      1.80
# 2     16.08
# 3     53.50
# 4      0.50
# 5      1.70
# 6      1.20
# 7      2.60
# 8      2.90
# 9      1.20
# 10     5.54
# 11     3.20
# 12     0.48
# 13    -0.70
# 14    -1.70
# 15     3.90
# Name: Last_inflation, dtype: float64

# %%
gh.Last_inflation.float64.replace('.','2').astype(int)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [313], in <cell line: 1>()
# ----> 1 gh.Last_inflation.float64.replace('.','2').astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'float64'

# %%
gh.groupby['order date week']['Last_inflation'].sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [314], in <cell line: 1>()
# ----> 1 gh.groupby['order date week']['Last_inflation'].sum()
#
# TypeError: 'method' object is not subscriptable

# %%
data={'name':['sudh','krish','hitesh','telusko'],
     'salary':[100,200,300,400],
     'mail_id':['sudh@ineuron.ai','krish@ineuron.ai','hitesh@ineuron.ai','telusko@ineuron.ai'],
      'addr':['blr','blr','blr','mum']}

# %%
cp=pd.DataFrame(data)

# %%
cp1=pd.DataFrame(data,index=[30,31,32,34])

# %%
cp
# Out:
#       name  salary             mail_id addr
# 0     sudh     100     sudh@ineuron.ai  blr
# 1    krish     200    krish@ineuron.ai  blr
# 2   hitesh     300   hitesh@ineuron.ai  blr
# 3  telusko     400  telusko@ineuron.ai  mum

# %%
cp1.iloc[0:3]
# Out:
#       name  salary            mail_id addr
# 30    sudh     100    sudh@ineuron.ai  blr
# 31   krish     200   krish@ineuron.ai  blr
# 32  hitesh     300  hitesh@ineuron.ai  blr

# %%
cp1.loc[[0,3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [335], in <cell line: 1>()
# ----> 1 cp1.loc[[0,3]]
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:967, in _LocationIndexer.__getitem__(self, key)
#     964 axis = self.axis or 0
#     966 maybe_callable = com.apply_if_callable(key, self.obj)
# --> 967 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1191, in _LocIndexer._getitem_axis(self, key, axis)
#    1188     if hasattr(key, "ndim") and key.ndim > 1:
#    1189         raise ValueError("Cannot index with multidimensional key")
# -> 1191     return self._getitem_iterable(key, axis=axis)
#    1193 # nested tuple slicing
#    1194 if is_nested_tuple(key, labels):
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1132, in _LocIndexer._getitem_iterable(self, key, axis)
#    1129 self._validate_key(key, axis)
#    1131 # A collection of keys
# -> 1132 keyarr, indexer = self._get_listlike_indexer(key, axis)
#    1133 return self.obj._reindex_with_indexers(
#    1134     {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#    1135 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1327, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1324 ax = self.obj._get_axis(axis)
#    1325 axis_name = self.obj._get_axis_name(axis)
# -> 1327 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1329 return keyarr, indexer
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5842, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5840     if use_interval_msg:
#    5841         key = list(key)
# -> 5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Int64Index([0, 3], dtype='int64')] are in the [index]"

# %%
cp1.loc[31:34]
# Out:
#        name  salary             mail_id addr
# 31    krish     200    krish@ineuron.ai  blr
# 32   hitesh     300   hitesh@ineuron.ai  blr
# 34  telusko     400  telusko@ineuron.ai  mum

# %%
cp1.loc[[31,32]]
# Out:
#       name  salary            mail_id addr
# 31   krish     200   krish@ineuron.ai  blr
# 32  hitesh     300  hitesh@ineuron.ai  blr

# %%
data1={'pf_no':[234,25,252,345],
       'income_tax':[245,56,458,5554],
       'mobile_no':[756546465,546546454,5246566785,7585465456],
       'courses':['ds','fs','ms','dd']}

# %%
cps=pd.DataFrame(data1)

# %%
cps
# Out:
#    pf_no  income_tax   mobile_no courses
# 0    234         245   756546465      ds
# 1     25          56   546546454      fs
# 2    252         458  5246566785      ms
# 3    345        5554  7585465456      dd

# %%
cp
# Out:
#       name  salary             mail_id addr
# 0     sudh     100     sudh@ineuron.ai  blr
# 1    krish     200    krish@ineuron.ai  blr
# 2   hitesh     300   hitesh@ineuron.ai  blr
# 3  telusko     400  telusko@ineuron.ai  mum

# %%
pd.concat([cp,cps])
# Out:
#       name  salary             mail_id addr  pf_no  income_tax     mobile_no  \
# 0     sudh   100.0     sudh@ineuron.ai  blr    NaN         NaN           NaN
# 1    krish   200.0    krish@ineuron.ai  blr    NaN         NaN           NaN
# 2   hitesh   300.0   hitesh@ineuron.ai  blr    NaN         NaN           NaN
# 3  telusko   400.0  telusko@ineuron.ai  mum    NaN         NaN           NaN
# 0      NaN     NaN                 NaN  NaN  234.0       245.0  7.565465e+08
# 1      NaN     NaN                 NaN  NaN   25.0        56.0  5.465465e+08
# 2      NaN     NaN                 NaN  NaN  252.0       458.0  5.246567e+09
# 3      NaN     NaN                 NaN  NaN  345.0      5554.0  7.585465e+09
#
#   courses
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 0      ds
# 1      fs
# 2      ms
# 3      dd

# %%
# the above is for horizontal addition of data(when column names are different#

# %%
df=pd.concat([cp,cps],axis=1)

# %%
df
# Out:
#       name  salary             mail_id addr  pf_no  income_tax   mobile_no  \
# 0     sudh     100     sudh@ineuron.ai  blr    234         245   756546465
# 1    krish     200    krish@ineuron.ai  blr     25          56   546546454
# 2   hitesh     300   hitesh@ineuron.ai  blr    252         458  5246566785
# 3  telusko     400  telusko@ineuron.ai  mum    345        5554  7585465456
#
#   courses
# 0      ds
# 1      fs
# 2      ms
# 3      dd

# %%
# vertical addition of data (when column names are different)#

# %%
data2={'0':[234,25,252,345],
       '1':[245,56,458,5554],
       '2':[756546465,546546454,5246566785,7585465456],
       '3':['ds','fs','ms','dd']}

# %%
data3={'0':['sudh','krish','hitesh','telusko'],
     '1':[100,200,300,400],
     '2':['sudh@ineuron.ai','krish@ineuron.ai','hitesh@ineuron.ai','telusko@ineuron.ai'],
      '3':['blr','blr','blr','mum']}

# %%
cpd=pd.DataFrame(data2)

# %%
cpd
# Out:
#      0     1           2   3
# 0  234   245   756546465  ds
# 1   25    56   546546454  fs
# 2  252   458  5246566785  ms
# 3  345  5554  7585465456  dd

# %%
cpd1=pd.DataFrame(data3)

# %%
cpd1
# Out:
#          0    1                   2    3
# 0     sudh  100     sudh@ineuron.ai  blr
# 1    krish  200    krish@ineuron.ai  blr
# 2   hitesh  300   hitesh@ineuron.ai  blr
# 3  telusko  400  telusko@ineuron.ai  mum

# %%
pd.concat([cpd,cpd1])
# Out:
#          0     1                   2    3
# 0      234   245           756546465   ds
# 1       25    56           546546454   fs
# 2      252   458          5246566785   ms
# 3      345  5554          7585465456   dd
# 0     sudh   100     sudh@ineuron.ai  blr
# 1    krish   200    krish@ineuron.ai  blr
# 2   hitesh   300   hitesh@ineuron.ai  blr
# 3  telusko   400  telusko@ineuron.ai  mum

# %%
# in the above it is row addition which columns index are same in both dataframes#

# %%
pd.concat([cpd,cpd1],axis=1)
# Out:
#      0     1           2   3        0    1                   2    3
# 0  234   245   756546465  ds     sudh  100     sudh@ineuron.ai  blr
# 1   25    56   546546454  fs    krish  200    krish@ineuron.ai  blr
# 2  252   458  5246566785  ms   hitesh  300   hitesh@ineuron.ai  blr
# 3  345  5554  7585465456  dd  telusko  400  telusko@ineuron.ai  mum

# %%
# inthe above case it is column addition and also row index are same#

# %%
df
# Out:
#       name  salary             mail_id addr  pf_no  income_tax   mobile_no  \
# 0     sudh     100     sudh@ineuron.ai  blr    234         245   756546465
# 1    krish     200    krish@ineuron.ai  blr     25          56   546546454
# 2   hitesh     300   hitesh@ineuron.ai  blr    252         458  5246566785
# 3  telusko     400  telusko@ineuron.ai  mum    345        5554  7585465456
#
#   courses
# 0      ds
# 1      fs
# 2      ms
# 3      dd

# %%
df[['name','mail_id']]
# Out:
#       name             mail_id
# 0     sudh     sudh@ineuron.ai
# 1    krish    krish@ineuron.ai
# 2   hitesh   hitesh@ineuron.ai
# 3  telusko  telusko@ineuron.ai

# %%
df[df['name']=='sudh']['mail_id']
# Out:
# 0    sudh@ineuron.ai
# Name: mail_id, dtype: object

# %%
cp
# Out:
#       name  salary             mail_id addr
# 0     sudh     100     sudh@ineuron.ai  blr
# 1    krish     200    krish@ineuron.ai  blr
# 2   hitesh     300   hitesh@ineuron.ai  blr
# 3  telusko     400  telusko@ineuron.ai  mum

# %%
df
# Out:
#       name  salary             mail_id addr  pf_no  income_tax   mobile_no  \
# 0     sudh     100     sudh@ineuron.ai  blr    234         245   756546465
# 1    krish     200    krish@ineuron.ai  blr     25          56   546546454
# 2   hitesh     300   hitesh@ineuron.ai  blr    252         458  5246566785
# 3  telusko     400  telusko@ineuron.ai  mum    345        5554  7585465456
#
#   courses
# 0      ds
# 1      fs
# 2      ms
# 3      dd

# %%
pd.merge(cp,df)
# Out:
#       name  salary             mail_id addr  pf_no  income_tax   mobile_no  \
# 0     sudh     100     sudh@ineuron.ai  blr    234         245   756546465
# 1    krish     200    krish@ineuron.ai  blr     25          56   546546454
# 2   hitesh     300   hitesh@ineuron.ai  blr    252         458  5246566785
# 3  telusko     400  telusko@ineuron.ai  mum    345        5554  7585465456
#
#   courses
# 0      ds
# 1      fs
# 2      ms
# 3      dd

# %%
pd.merge(cp,cps)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Input In [379], in <cell line: 1>()
# ----> 1 pd.merge(cp,cps)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:107, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      90 @Substitution("\nleft : DataFrame or named Series")
#      91 @Appender(_merge_doc, indents=0)
#      92 def merge(
#    (...)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#     110         how=how,
#     111         on=on,
#     112         left_on=left_on,
#     113         right_on=right_on,
#     114         left_index=left_index,
#     115         right_index=right_index,
#     116         sort=sort,
#     117         suffixes=suffixes,
#     118         copy=copy,
#     119         indicator=indicator,
#     120         validate=validate,
#     121     )
#     122     return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:682, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     678     # stacklevel chosen to be correct when this is reached via pd.merge
#     679     # (and not DataFrame.join)
#     680     warnings.warn(msg, FutureWarning, stacklevel=find_stack_level())
# --> 682 self._validate_specification()
#     684 cross_col = None
#     685 if self.how == "cross":
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py:1349, in _MergeOperation._validate_specification(self)
#    1347 common_cols = left_cols.intersection(right_cols)
#    1348 if len(common_cols) == 0:
# -> 1349     raise MergeError(
#    1350         "No common columns to perform merge on. "
#    1351         f"Merge options: left_on={self.left_on}, "
#    1352         f"right_on={self.right_on}, "
#    1353         f"left_index={self.left_index}, "
#    1354         f"right_index={self.right_index}"
#    1355     )
#    1356 if (
#    1357     not left_cols.join(common_cols, how="inner").is_unique
#    1358     or not right_cols.join(common_cols, how="inner").is_unique
#    1359 ):
#    1360     raise MergeError(f"Data columns not unique: {repr(common_cols)}")
#
# MergeError: No common columns to perform merge on. Merge options: left_on=None, right_on=None, left_index=False, right_index=False

# %%
data5={'pf_no':[234,25,252,444],
       'income_tax':[245,56,458,5554],
       'mobile_no':[756546465,546546454,5246566785,7585465456],
       'courses':['ds','fs','ms','df']}

# %%
df1=pd.DataFrame(data5)

# %%
pd.merge(df,df1)
# Out:
#      name  salary            mail_id addr  pf_no  income_tax   mobile_no  \
# 0    sudh     100    sudh@ineuron.ai  blr    234         245   756546465
# 1   krish     200   krish@ineuron.ai  blr     25          56   546546454
# 2  hitesh     300  hitesh@ineuron.ai  blr    252         458  5246566785
#
#   courses
# 0      ds
# 1      fs
# 2      ms

# %%
# merge operation will give the common rows with all columns  from the both of the dataframes#

# %%
pd.merge(df,df1,'left')
# Out:
#       name  salary             mail_id addr  pf_no  income_tax   mobile_no  \
# 0     sudh     100     sudh@ineuron.ai  blr    234         245   756546465
# 1    krish     200    krish@ineuron.ai  blr     25          56   546546454
# 2   hitesh     300   hitesh@ineuron.ai  blr    252         458  5246566785
# 3  telusko     400  telusko@ineuron.ai  mum    345        5554  7585465456
#
#   courses
# 0      ds
# 1      fs
# 2      ms
# 3      dd

# %%
pd.merge(df,df1,'right')
# Out:
#      name  salary            mail_id addr  pf_no  income_tax   mobile_no  \
# 0    sudh   100.0    sudh@ineuron.ai  blr    234         245   756546465
# 1   krish   200.0   krish@ineuron.ai  blr     25          56   546546454
# 2  hitesh   300.0  hitesh@ineuron.ai  blr    252         458  5246566785
# 3     NaN     NaN                NaN  NaN    444        5554  7585465456
#
#   courses
# 0      ds
# 1      fs
# 2      ms
# 3      df

# %%
pd.merge(df,df1,'inner')
# Out:
#      name  salary            mail_id addr  pf_no  income_tax   mobile_no  \
# 0    sudh     100    sudh@ineuron.ai  blr    234         245   756546465
# 1   krish     200   krish@ineuron.ai  blr     25          56   546546454
# 2  hitesh     300  hitesh@ineuron.ai  blr    252         458  5246566785
#
#   courses
# 0      ds
# 1      fs
# 2      ms

# %%
## inner merge and merge both are same#

# %%
pd.merge(df,df1,'outer')
# Out:
#       name  salary             mail_id addr  pf_no  income_tax   mobile_no  \
# 0     sudh   100.0     sudh@ineuron.ai  blr    234         245   756546465
# 1    krish   200.0    krish@ineuron.ai  blr     25          56   546546454
# 2   hitesh   300.0   hitesh@ineuron.ai  blr    252         458  5246566785
# 3  telusko   400.0  telusko@ineuron.ai  mum    345        5554  7585465456
# 4      NaN     NaN                 NaN  NaN    444        5554  7585465456
#
#   courses
# 0      ds
# 1      fs
# 2      ms
# 3      dd
# 4      df

# %%
# outer merge gives common plus distinct data#

# %%
data6={'pf_no1':[234,25,252,444],
       'income_tax1':[245,56,458,5554]}
data7={'pf_no2':[234,25,252,444],
       'mobile_no':[756546465,546546454,5246566785,7585465456],
       'courses':['ds','fs','ms','df']}

# %%
df3=pd.DataFrame(data6)

# %%
df3
# Out:
#    pf_no1  income_tax1
# 0     234          245
# 1      25           56
# 2     252          458
# 3     444         5554

# %%
df4=pd.DataFrame(data7)

# %%
df4
# Out:
#    pf_no2   mobile_no courses
# 0     234   756546465      ds
# 1      25   546546454      fs
# 2     252  5246566785      ms
# 3     444  7585465456      df

# %%
pd.merge(df3,df4,left_on='pf_no1',right_on='pf_no2',how='inner')
# Out:
#    pf_no1  income_tax1  pf_no2   mobile_no courses
# 0     234          245     234   756546465      ds
# 1      25           56      25   546546454      fs
# 2     252          458     252  5246566785      ms
# 3     444         5554     444  7585465456      df

# %%
## the above is simillar to column addition##

# %%
data8={'pf_no':[234,25,2534,444],
       'income_tax':[245,56,458,5554],
       'mobile_no':[756546465,546546454,5246566785,7585465456],
       'courses':['ds','fs','ms','df']}
data9={'pf_no':[234,25,2522,444],
       'income_tax':[245,562,458,5554],
       'mobile_no':[756546465,5456546454,5246566785,7585465456],
       'courses':['ds','fs','ms','df']}

# %%
df6=pd.DataFrame(data8)

# %%
df6
# Out:
#    pf_no  income_tax   mobile_no courses
# 0    234         245   756546465      ds
# 1     25          56   546546454      fs
# 2   2534         458  5246566785      ms
# 3    444        5554  7585465456      df

# %%
df7=pd.DataFrame(data9)

# %%
df7
# Out:
#    pf_no  income_tax   mobile_no courses
# 0    234         245   756546465      ds
# 1     25         562  5456546454      fs
# 2   2522         458  5246566785      ms
# 3    444        5554  7585465456      df

# %%
pd.merge(df6,df7,on=['pf_no','income_tax','mobile_no'])
# Out:
#    pf_no  income_tax   mobile_no courses_x courses_y
# 0    234         245   756546465        ds        ds
# 1    444        5554  7585465456        df        df

# %%
# above is to merge those data when 3 of the conditions are satisfied"

# %%
def mobnumber(a):
    b=str(a)
    if len(b)==10:
        return 'correct'
    else:
        return 'wrong number'

# %%
mobnumber(10000)
# Out:
# 'wrong number'

# %%
df7['mob number verify']=df7['mobile_no'].apply(mobnumber)

# %%
df7
# Out:
#    pf_no  income_tax   mobile_no courses mob number verify
# 0    234         245   756546465      ds      wrong number
# 1     25         562  5456546454      fs           correct
# 2   2522         458  5246566785      ms           correct
# 3    444        5554  7585465456      df           correct

# %%
## in the above we did the operation using user defined function##

# %%
a
# Out:
#      Dress_ID    Price  Rating Size NeckLine SleeveLength waiseline  \
# 0  1006032852      Low     4.6    M   o-neck    sleevless    empire
# 1  1212192089      Low     0.0    L   o-neck        Petal   natural
# 2  1190380701     High     0.0    L   o-neck         full   natural
# 3   966005983  Average     4.6    L   o-neck         full   natural
# 4   876339541      Low     4.5    M   o-neck    butterfly   natural
#
#         Material FabricType  Decoration Pattern Type  Recommendation
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0

# %%
def fashion(a):
    if a=='o-neck':
        return 'old-fashion'
    else:
        return 'new-fashion'

# %%
a['Neck_line_fashion']=a['NeckLine'].apply(fashion)

# %%
a.tail()
# Out:
#      Dress_ID    Price  Rating Size NeckLine SleeveLength waiseline  \
# 0  1006032852      Low     4.6    M   o-neck    sleevless    empire
# 1  1212192089      Low     0.0    L   o-neck        Petal   natural
# 2  1190380701     High     0.0    L   o-neck         full   natural
# 3   966005983  Average     4.6    L   o-neck         full   natural
# 4   876339541      Low     4.5    M   o-neck    butterfly   natural
#
#         Material FabricType  Decoration Pattern Type  Recommendation  \
# 0            NaN    chiffon     ruffles       animal               1
# 1     microfiber        NaN     ruffles       animal               0
# 2       polyster        NaN         NaN        print               0
# 3           silk    chiffon  embroidary        print               1
# 4  chiffonfabric    chiffon         bow          dot               0
#
#   Neck_line_fashion
# 0       old-fashion
# 1       old-fashion
# 2       old-fashion
# 3       old-fashion
# 4       old-fashion

# %%
## numpy class###

# %%
import numpy as np

# %%
np.array([2,3,4,5])
# Out:
# array([2, 3, 4, 5])

# %%
fh=np.array([1,2,3,40],ndmin=5)

# %%
fh
# Out:
# array([[[[[ 1,  2,  3, 40]]]]])

# %%
fh1=np.array([[[1,2,3],[2,3,4]]])

# %%
fh1.ndim
# Out:
# 3
